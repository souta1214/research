# %% [markdown]
# <font size="5">ライブラリのインポート

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset
import numpy as np
import matplotlib.pyplot as plt
import random
import math
import pandas as pd
import csv

# %% [markdown]
# <font size="5">cpuとgpuの選択

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "gpu")

# %% [markdown]
# <font size="5">乱数を特定の値にして再現性を確保

# %%
# For reproducibility
torch.manual_seed(42)
if use_cuda:
    torch.cuda.manual_seed(42)

# %% [markdown]
# <font size ="5">pytorch用データセットの作成

# %%
# Load MNIST dataset
# pytorchではTensorというデータ構造で、モデルの入力、出力、パラメータを表現
# 前処理の定義
"""
これから取得するDatasetの中身がndarray型のデータ集合であるため、前処理でtensor型にしたい

root
Datasetを参照(または保存)するディレクトリを「path」の部分に指定する.
そのディレクトリに取得したいDatasetが存在すればダウンロードせずにそれを使用する.

train
Training用のdataを取得するかどうかを選択する.
FalseにすればTest用のdataを取得するが,この2つの違いはdata数の違いと思ってくれて良い.

download
rootで参照したディレクトリにDatasetがない場合ダウンロードするかどうかを決めることができる.

transform
定義した前処理を渡す.
こうすることでDataset内のdataを参照する時にその前処理を自動で行ってくれる.
"""
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# 学習用データとテスト用データの取得
# transformは私用すると前処理を指定できる
# これによりdatasetをdetaloaderに渡して使える状態にした
train_dataset_original = datasets.FashionMNIST(root='./data', train=True, transform=transform, download=True)
print(f"Train Dataset Size: {len(train_dataset_original)}")
test_dataset_original = datasets.FashionMNIST(root='./data', train=False, transform=transform)
print(f"Test Dataset Size: {len(test_dataset_original)}")
# Out:
# Train Dataset Size: 60000
# Test Dataset Size: 10000
# C:\Users\y9723\anaconda3\lib\site-packages\torchvision\datasets\mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ..\torch\csrc\utils\tensor_numpy.cpp:180.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %% [markdown]
# <font size ="5">データの個数を調節

# %%
# traindata
# クラス数を取得
num_classes = len(train_dataset_original.classes)
print(num_classes)
print(len(train_dataset_original))
# 各クラスごとのデータ数を計算
desired_class_count = 3000  # 各クラスごとに均等に分割したいデータ数
total_desired_count = desired_class_count * num_classes

# クラスごとに均等にデータを分割するためのリストを作成
selected_indices_1 = []
selected_indices_2 = []

# 各クラスごとに均等にデータを選択
for class_idx in range(num_classes):
    class_indices = np.where(train_dataset_original.targets == class_idx)[0]
    np.random.shuffle(class_indices)
    selected_indices_1.extend(class_indices[:desired_class_count])
    selected_indices_2.extend(class_indices[desired_class_count:2*desired_class_count])

# 選択したデータで新しいデータセットを作成
train_data_1 = torch.utils.data.Subset(train_dataset_original, selected_indices_1)
train_data_2 = torch.utils.data.Subset(train_dataset_original, selected_indices_2)

# # 各クラスごとの新しいデータ数を確認
class_counts_subset_1 = np.bincount([train_dataset_original.targets[i] for i in selected_indices_1])
class_counts_subset_2 = np.bincount([train_dataset_original.targets[i] for i in selected_indices_2])

print("データセット1の各クラスごとの新しいデータ数:", class_counts_subset_1)
print("データセット2の各クラスごとの新しいデータ数:", class_counts_subset_2)

# testdata
# 2. データセット内のクラスごとのサンプル数を確認
class_count = [0] * 10# 10はFashionMNISTのクラス数です
sample_indices = []
for i in range(len(test_dataset_original)):
    _, target = test_dataset_original[i]
    if class_count[target] < 100:  # 各クラスから100サンプルまで抽出
        sample_indices.append(i)
        class_count[target] += 1

# 3. 均等に抽出されたサンプルから新しいデータセットを構築
test_data = torch.utils.data.Subset(test_dataset_original, sample_indices)

# 新しいデータセットを使用して必要な処理を実行

for i in range(len(test_data)):
    if class_count[target] < 100:  # 各クラスから100サンプルまで抽出
        sample_indices.append(i)
        class_count[target] += 1

# 各クラスごとのサンプル数を出力
for i, count in enumerate(class_count):
    print(f"クラス {i}: {count} 個のサンプル")
    
print(f"testデータの数：{len(test_data)}")
# Out:
# 10
# 60000
# データセット1の各クラスごとの新しいデータ数: [3000 3000 3000 3000 3000 3000 3000 3000 3000 3000]
# データセット2の各クラスごとの新しいデータ数: [3000 3000 3000 3000 3000 3000 3000 3000 3000 3000]
# クラス 0: 100 個のサンプル
# クラス 1: 100 個のサンプル
# クラス 2: 100 個のサンプル
# クラス 3: 100 個のサンプル
# クラス 4: 100 個のサンプル
# クラス 5: 100 個のサンプル
# クラス 6: 100 個のサンプル
# クラス 7: 100 個のサンプル
# クラス 8: 100 個のサンプル
# クラス 9: 100 個のサンプル
# testデータの数：1000

# %% [markdown]
# <font size ="5">Siamese Network用MNISTデータセットクラスの作成

# %%
# Siamese Network用MNISTデータセットクラスの作成
class SiameseMNIST(Dataset):
    def __init__(self, dataset):
        self.dataset=dataset
        self.length=len(self.dataset)
        self.pair_index=[]     # Siamese Net用画像ペアインデックス配列
        labels=[label for _, label in self.dataset]     # 入力されたデータセットからラベル情報のみ抽出
        positive_count=0     # positiveペアのカウント
        negative_count=0     # negativeペアのカウント
        random_index=np.arange(self.length)     # ？？？
        
        while positive_count + negative_count < self.length:
            np.random.shuffle(random_index)
            for i in np.arange(self.length):
                if labels[i]==labels[random_index[i]]:     # 画像ペアのラベルが等しい時（positive）
                    if positive_count<self.length/2:      # おそらく比率を同じにしたい？？
                        self.pair_index.append([i, random_index[i], 1])      # 要素の構成：[<画像1のインデックス>,<画像2のインデックス>,<posi:1/nega:0フラグ>]
                        positive_count+=1
                    else:
                        continue
                else:
                    if negative_count<self.length/2:
                        self.pair_index.append([i, random_index[i], 0])
                        negative_count+=1
                    else:
                        continue
#         print("com", self.pair_index)
    def __len__(self):
        return self.length

    def __getitem__(self, index):

        return self.dataset[self.pair_index[index][0]][0], self.dataset[self.pair_index[index][1]][0], torch.tensor(self.pair_index[index][2])

# %% [markdown]
# <font size ="5">Siamese Network学習用Dataset, DataLoaderの作成

# %%
batch_size=64
# 1 学習用
# train_dataset_1=SiameseMNIST(train_data_1) 
# train_data_learn=DataLoader(train_dataset_1, batch_size=batch_size, shuffle=True)
# # # 2 写像用(領域作成用)
# # train_data_projection=DataLoader(train_data_2, batch_size=1, shuffle=True)
# 3 テスト用
# test_loader=DataLoader(test_data, batch_size=1, shuffle=True)

batch_size=64
train_dataset=SiameseMNIST(train_dataset_original) 
train_loader=DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
train_loader_prime=DataLoader(train_dataset_original, batch_size=1, shuffle=False)

# %%
test_loader=DataLoader(test_data, batch_size=1, shuffle=False)

# %% [markdown]
# <font size ="5">ペア画像の確認

# %%
X1, X2, y = next(iter(train_loader))
print(X1[0].shape)
fig=plt.figure(tight_layout=True, figsize=(8, 16))
rows=10
for i in range(rows):
    print(f"y[{i}]={y[i]}")
    ax = fig.add_subplot(rows, 2, i*2+1)
    ax.imshow(X1[i][0].numpy(), cmap='gray')                          # X1[i].shape = (1, 28, 28)，X1[i][0].shape = (28, 28)
    ax = fig.add_subplot(rows, 2, i*2+2)
    ax.imshow(X2[i][0].numpy(), cmap='gray')
# Out:
# torch.Size([1, 28, 28])
# y[0]=0
# y[1]=1
# y[2]=1
# y[3]=1
# y[4]=1
# y[5]=1
# y[6]=0
# y[7]=0
# y[8]=1
# y[9]=0

# %% [markdown]
# <font size="5">モデルの構築

# %% [markdown]
# super()はあるクラス（子クラス）で別のクラス（親クラス）を継承できる。継承することで、親クラスのメソッドを子クラスから呼び出すことができる。
# 以下の形式
# super().親クラスのメソッド

# %%
class BaseNetwork(nn.Module):
    """
    Base network for Siamese Network.
    This will be shared between two input images.
    """
    def __init__(self):
        super().__init__()

        # Define the layers
        # Using similar architecture as in the Keras example

        # First Convolutional Layer
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm2d(32)
        self.act1 = nn.ReLU()
        self.maxpool1 = nn.MaxPool2d(kernel_size=2, stride=2)

        # Second Convolutional Layer
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(64)
        self.act2 = nn.ReLU()
        self.maxpool2 = nn.MaxPool2d(kernel_size=2, stride=2)

        # Flatten and Dense Layers
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(64 * 7 * 7, 128)  # Assuming input image size is 28x28
        self.act3 = nn.ReLU()
        self.dropout = nn.Dropout(0.5)
        self.fc2 = nn.Linear(128, 256)
        self.act4 = nn.ReLU()

    def forward_1(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.act1(x)
        x = self.maxpool1(x)

        x = self.conv2(x)
        x = self.bn2(x)
        x = self.act2(x)
        x = self.maxpool2(x)

        x = self.flatten(x)
        x = self.fc1(x)
        x = self.act3(x)
        x = self.dropout(x)
        x = self.fc2(x)
#         print("xのshape",x)
        x = self.act4(x)

        return x

    def forward(self, x1,x2):
        z1=self.forward_1(x1)
        z2=self.forward_1(x2)
        return z1,z2

# Test the base network with a sample input
base_network = BaseNetwork().to(device)
sample_input = torch.randn(8, 1, 28, 28).to(device)  # Batch of 8 images of sizammm28x28 with 1 channel
sample_output = base_network.forward_1(sample_input)

sample_output.shape  # Expected: [8, 256]
# Out:
# C:\Users\y9723\anaconda3\lib\site-packages\torch\nn\functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  ..\c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# torch.Size([8, 256])

# %%
# Siamse Networkモデルクラス
import torch.nn as nn

class SiameseCNNMnistModel(nn.Module):
    
    def __init__(self):
        super().__init__()

        self.encoder = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=5, padding=2), # 28x28x32
            nn.ReLU(),
            nn.MaxPool2d(2,2),                         # 14x14x32
            nn.Conv2d(32, 64, kernel_size=5, padding=2),# 14x14x64
            nn.ReLU(),
            nn.MaxPool2d(2,2)                          # 7x7x64
        )

        # Fully connected layers to get embeddings
        self.fc = nn.Sequential(
            nn.Linear(7*7*64, 256),
            nn.ReLU(),
            nn.Linear(256, 3)
        )
    
    def forward_once(self, x):
        x = self.encoder(x)
        x = x.view(x.size()[0], -1)  # Flatten
        z = self.fc(x)
        return z
  
    def forward(self, x1, x2):
        z1 = self.forward_once(x1)
        z2 = self.forward_once(x2)
        return z1, z2

# %% [markdown]
# <font size="5">損失関数

# %%
# 損失関数
class ContrastiveLoss(nn.Module):
    def __init__(self, margin=2.5):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, z1, z2, y):
        difference = z1 - z2
        distance_squared = torch.sum(torch.pow(difference, 2), 1)
        distance = torch.sqrt(distance_squared)       #平均：0.813，最大：1.663，最小：0.023，中央値：0.492
        negative_distance = self.margin - distance
        negative_distance = torch.clamp(negative_distance, min=0.0)
        loss = (abs(y) * (distance_squared+2) + abs(1 - abs(y)) * torch.pow(negative_distance, 2)) / 2.0
        loss = torch.sum(loss) / z1.size()[0]
        return loss

# %% [markdown]
# <font size ="5">使用関数の一覧実行

# %%
#u,vの更新関数
def u_optimize(d):
    u=np.zeros((data_size, class_num+1)) # +1はノイズ分
    for k in range(data_size):
        if 0 not in d[k]:
            for i in range(class_num+1):
                for j in range(class_num+1):
                    u[k][i] = u[k][i] + (d[k][i]/d[k][j])**(1/(m-1))
                u[k][i]=1/u[k][i]
        else:
            for i in range(class_num):
                if d[k][i]==0:
                    u[k][i] = 1
                else:
                    u[k][i]=0
    return u

def v_optimize(u_prime):
    u_except_noise = u_prime[:,1:]
    v = np.zeros((class_num,n_features))
    #分母計算
    v_denominator=np.sum(u_except_noise,axis=0)
    #分子計算
    v_numerator = np.zeros((class_num,n_features))
    for i in range(class_num):
        for k in range(data_size):
            v_numerator[i]=v_numerator[i]+u_except_noise[k][i]*z_valid_np[k]
    for i in range(class_num):
        v[i]= v_numerator[i]/v_denominator[i]
    return v

def noise_clustering(data_size, class_num, max_iter, m, gamma, J, best_J):
    for s in range(max_iter):
        # 初期クラスター中心
        v=z_valid_np[np.random.choice(data_size, class_num)]
        for epoch in range(max_iter):
            for k in range(data_size):
                # データから各重心までの距離の二乗を計算
                d[k][1:]=np.sum((v-z_valid_np[k])**2, axis=1)
            # uの更新
            u=u_optimize(d)
            u_prime=np.power(u, m)
            # vの更新
            v_prime=v_optimize(u_prime)
            #収束条件作成
            for i in range(class_num):
                v_difference = np.linalg.norm(v_prime[i]-v[i], ord=2)
            #収束判定
            if v_difference.min() < epsilon:
                break
            #値のリセット
            v = np.copy(v_prime)


        # 目的関数の計算
        J = np.sum(u_prime[:,1:] * d[:,1:]) + np.sum(u_prime[:,0] * (gamma)**2)
        # 目的関数の値を最適化
        if s==0 or J < best_J:
            best_J = J
            best_u = np.copy(u)
            best_v = np.copy(v_prime)
            #帰属クラスターの決定と格納
            cluster = np.argmax(best_u,axis=1)
    print("クラスター中心は")
    print(best_v.shape)
    print(best_v)
    print("目的関数は"+str(best_J))
    print(cluster)
    return best_v, cluster

# %%
# 距離関数
def calculate_distances(data1, data2):
    # data1 の各行と data2 とのユークリッド距離を計算
    distances = np.linalg.norm(data1 - data2, axis=1)

    return distances

def calculate_distances_normal(data1, data2):
    # numpyのユークリッド距離関数を使用して距離を計算
    distance = np.linalg.norm(data1 - data2)
    return distance


#重心を算出
def caluc_cluster(data, labels, i, class_num):
    x_1 = np.mean(data[labels==i, 0], axis=0)
    y_1 = np.mean(data[labels==i, 1], axis=0)
    z_1 = np.mean(data[labels==i, 2], axis=0)
    centroids=(x_1, y_1, z_1)
#     print("ラベル", i, "の重心：", x_1, y_1, z_1)
    return centroids

# ノイズクラスタリング


# 単位球面上に写像する関数
def norm(data):
    norm_data=data.copy()
    for i in range(len(data)):
        norm_data[i]=data[i] / np.linalg.norm(data[i], ord=2)
    return norm_data


def caluc_rotation_main(data):
    # 値の入力
    x=data[0, 0]
    y=data[0, 1]
    z=data[0, 2]
    
    # xの回転
    theta_1 = np.arctan2(y, z)
    
    x_rot_0 = x
    x_rot_1 = y*np.cos(theta_1) - z*np.sin(theta_1)
    x_rot_2 = y*np.sin(theta_1)+z*np.cos(theta_1)
    
    # 値の更新
    x=x_rot_0
    y=x_rot_1
    z=x_rot_2
    
    # yの回転
    theta_2 = np.arctan2(-x, z)
    
    y_rot_0 = x*np.cos(theta_2) + z*np.sin(theta_2)
    y_rot_1 = y
    y_rot_2 = -x*np.sin(theta_2) + z*np.cos(theta_2)
    
    ans=(y_rot_0, y_rot_1, y_rot_2)
    theta=theta_1, theta_2
    
    return ans, theta

def caluc_rotation_sub(data, theta):
    ans=np.zeros((9,3))
    for i in range(1,data.shape[0]):
        # 値の入力
        x=data[i, 0]
        y=data[i, 1]
        z=data[i, 2]

        # xの回転
        theta_1 = theta[0]

        x_rot_0 = x
        x_rot_1 = y*np.cos(theta_1) - z*np.sin(theta_1)
        x_rot_2 = y*np.sin(theta_1)+z*np.cos(theta_1)

        # 値の更新
        x=x_rot_0
        y=x_rot_1
        z=x_rot_2

        # yの回転
        theta_2 = theta[1]

        y_rot_0 = x*np.cos(theta_2) + z*np.sin(theta_2)
        y_rot_1 = y
        y_rot_2 = -x*np.sin(theta_2) + z*np.cos(theta_2)
        print(i)
        ans[i-1]=(y_rot_0, y_rot_1, y_rot_2)
    
    return ans

def caluc_rotation_data(data, theta):
    ans=np.zeros((data.shape[0],data.shape[1]))
#     print(ans.shape)
    for i in range(data.shape[1]):
        # 値の入力
        x=data[:, 0]
        y=data[:, 1]
        z=data[:, 2]

        # xの回転
        theta_1 = theta[0]

        x_rot_0 = x
        x_rot_1 = y*np.cos(theta_1) - z*np.sin(theta_1)
        x_rot_2 = y*np.sin(theta_1)+z*np.cos(theta_1)

        # 値の更新
        x=x_rot_0
        y=x_rot_1
        z=x_rot_2

        # yの回転
        theta_2 = theta[1]

        y_rot_0 = x*np.cos(theta_2) + z*np.sin(theta_2)
        y_rot_1 = y
        y_rot_2 = -x*np.sin(theta_2) + z*np.cos(theta_2)
        ans=(y_rot_0, y_rot_1, y_rot_2)
        
    
    return ans

# %% [markdown]
# <font size ="5">学習の準備

# %%
import torch.optim as optim
from torchsummary import summary

#モデルのインスタンス化
model=SiameseCNNMnistModel().to(device)
print(model.parameters)
# ？？？？
summary(model, input_size=[(1, 28, 28), (1, 28, 28)])      # 入力が２つあるので（ペア画像だから）input_sizeはリストで複数指定する

# 最適化関数の定義
optimizer=optim.SGD(model.parameters(), lr=0.05)

# 損失関数のインスタンス化
criterion=ContrastiveLoss()
# Out:
# <bound method Module.parameters of SiameseCNNMnistModel(
#   (encoder): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc): Sequential(
#     (0): Linear(in_features=3136, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=3, bias=True)
#   )
# )>
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 28, 28]             832
#               ReLU-2           [-1, 32, 28, 28]               0
#          MaxPool2d-3           [-1, 32, 14, 14]               0
#             Conv2d-4           [-1, 64, 14, 14]          51,264
#               ReLU-5           [-1, 64, 14, 14]               0
#          MaxPool2d-6             [-1, 64, 7, 7]               0
#             Linear-7                  [-1, 256]         803,072
#               ReLU-8                  [-1, 256]               0
#             Linear-9                    [-1, 3]             771
#            Conv2d-10           [-1, 32, 28, 28]             832
#              ReLU-11           [-1, 32, 28, 28]               0
#         MaxPool2d-12           [-1, 32, 14, 14]               0
#            Conv2d-13           [-1, 64, 14, 14]          51,264
#              ReLU-14           [-1, 64, 14, 14]               0
#         MaxPool2d-15             [-1, 64, 7, 7]               0
#            Linear-16                  [-1, 256]         803,072
#              ReLU-17                  [-1, 256]               0
#            Linear-18                    [-1, 3]             771
# ================================================================
# Total params: 1,711,878
# Trainable params: 1,711,878
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 2.34
# Forward/backward pass size (MB): 1.30
# Params size (MB): 6.53
# Estimated Total Size (MB): 10.17
# ----------------------------------------------------------------

# %% [markdown]
# <font size ="5">学習の実行

# %%
# import copy
# import matplotlib.pyplot as plt
# from tqdm.notebook import tqdm

# # モデル学習
# repeat = 60                                                      # 学習回数
# losses = []                                                       # 表示用損失値配列

# model.train()                                                     # 学習モード
# for epoch in range(repeat): 
#   print(f"epoch={epoch}")
#   nan_count = 0
#   normal_count = 0




#   # tqdmを使って学習の進行状況を表示
#   for X1, X2, y in tqdm(train_loader, desc=f"Epoch {epoch+1}/{repeat}"):                                  
#     # モデルによる特徴ベクトル算出
#     output1, output2 = model(X1.to(device), X2.to(device))

#     # 損失関数の計算
#     loss = criterion(output1, output2, y.to(device))

#     # nan対策（lossにnanが含まれていれば１回前のモデルに戻す）
#     if torch.isnan(loss):
#       model = prev_model
#       optimizer = optim.SGD(model.parameters(), lr=0.05)
#       optimizer.load_state_dict(prev_optimizer.state_dict())
#       nan_count += 1
#       continue
#     else:
#       prev_model = copy.deepcopy(model)
#       prev_optimizer = copy.deepcopy(optimizer)
#       normal_count += 1

#     # 表示用lossデータの記録
#     losses.append(loss.item())

#     # 勾配を初期化
#     optimizer.zero_grad()
    
#     # 損失関数の値から勾配を求め誤差逆伝播による学習実行
#     loss.backward()
    
#     # 学習結果に基づきパラメータを更新
#     optimizer.step()

#   print(f"nan/normal: {nan_count}/{normal_count}")
# plt.plot(losses)                                                  # loss値の推移を表示

# %% [markdown]
# <font size ="5">学習結果の保存

# %%
# torch.save(model.state_dict(), 'model_weights_Epochs_60_Margin_2_5_Alpha_02.pth')

# %% [markdown]
# <font size ="5">学習済みの重みを再利用する場合

# %%
model.load_state_dict(torch.load('model_weights_epochs_60_margin_2.5.pth'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# <font size ="5">モデルの出力ベクトルの取得

# %% [markdown]
# モデル学習の結果、同じクラスに属する画像の出力ベクトルは近くに、異なる数字に属する画像の出力ベクトルは遠くに配置されているはず。
# これを確認するために、テストデータを用いて出力ベクトルを集める。
# model.eval()で評価モードに設定し、変数の勾配も再計算されないようにtorch.no_grid()を記述する。

# %%
# モデル評価
model.eval()                                                      # 評価モード
with torch.no_grad():
    z_valid = []
    y_valid = []
    for X, y in train_loader_prime:                                      # テスト用DataLoader
        z_valid.append(model.forward_once(X.to(device)))           # テストデータをモデルに通して出力ベクトルを得る
        y_valid.append(y)                                          # ラベル（靴、シャツ）の代わりにラベルIDとして0～9の数代わり振られている
    z_valid = torch.cat(z_valid, dim=0)                             # 多次元torch.tensor要素のリストをtorch.tensor化
    y_valid = torch.tensor(y_valid)                                 # スカラ要素(int)リストをtorch.tensor化

# %%
# 次元数の確認
print(z_valid.size())
print(y_valid.size())
# Out:
# torch.Size([60000, 3])
# torch.Size([60000])

# %% [markdown]
# z_testとy_testをGPUに移動

# %%
# GPUが利用可能かチェック
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

# z_validとy_validをGPUに移動
z_valid = z_valid.to(device)
y_valid = y_valid.to(device)
# ndarrayに変換
z_valid_np = z_valid.to('cpu').detach().numpy().copy()
y_valid_np = y_valid.to('cpu').detach().numpy().copy()
print(z_valid_np.shape)
print(y_valid_np.shape)
# Out:
# (60000, 3)
# (60000,)

# %% [markdown]
# <font size="5">モデル出力ベクトルの分布可視化

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# クラス名
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# クラス数
class_num=len(class_names)
# 事前に定義された10色のリスト
colors = ["blue","green","red","cyan","magenta","yellow","black",'purple','#a65628','#ff7f00']
# figureを生成する
plt.figure(figsize=(10, 10))
# axをfigureに設定する
ax = plt.subplot(111, projection='3d')
# クラスごとに色を分けてプロット
for i in range(class_num):    ax.scatter(z_valid_np[y_valid_np==i, 0], z_valid_np[y_valid_np==i, 1], z_valid_np[y_valid_np==i, 2], color=colors[i], label=class_names[i])
ax.legend()  # 凡例の追加
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# クラス名
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# クラス数
class_num=len(class_names)
# 事前に定義された10色のリスト
colors = ["blue","green","red","cyan","magenta","yellow","black",'purple','#a65628','#ff7f00']
# figureを生成する
plt.figure(figsize=(10, 10))
# axをfigureに設定する
ax = plt.subplot(111, projection='3d')
# クラスごとに色を分けてプロット
ax.scatter(z_valid_np[y_valid_np==6, 0], z_valid_np[y_valid_np==6, 1], z_valid_np[y_valid_np==6, 2], color=colors[6], label=class_names[6])
ax.scatter(z_valid_np[y_valid_np==0, 0], z_valid_np[y_valid_np==0, 1], z_valid_np[y_valid_np==0, 2], color=colors[0], label=class_names[0])
ax.scatter(z_valid_np[y_valid_np==2, 0], z_valid_np[y_valid_np==2, 1], z_valid_np[y_valid_np==2, 2], color=colors[2], label=class_names[2])

ax.legend()  # 凡例の追加
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# <font size="5">ノイズクラスタリングなし

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


# 重心格納用のリスト
centroids=np.zeros((class_num, 3))
# クラス名
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# クラス数
class_num=len(class_names)
# 事前に定義された10色のリスト
colors = ["blue","green","red","cyan","magenta","yellow","black",'#f781bf','#a65628','#ff7f00']
# figureを生成する
plt.figure(figsize=(10, 10))
# axをfigureに設定する
ax = plt.subplot(111, projection='3d')

# 重心の算出
for i in range(class_num):
    centroids[i]=caluc_cluster(z_valid_np, y_valid_np, i, class_num)

# クラスごとに色を分けてプロット
for i in range(class_num):
#     ax.scatter(z_valid_np[y_valid_np==i, 0], z_valid_np[y_valid_np==i, 1], z_valid_np[y_valid_np==i, 2], color=colors[i], label=class_names[i])
    ax.scatter(centroids[i, 0], centroids[i, 1], centroids[i, 2], marker='*', color=colors[i], label=class_names[i], s=500, edgecolors="black")
ax.legend()  # 凡例の追加
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# <font size="5">ノイズクラスタリングあり

# %% [markdown]
# <font size="5">ノイズクラスタリングありなしの比較

# %% [markdown]
# <font size="5">判定領域作成関数

# %% [markdown]
# 判定領域作成のステップを以下に示す
# １．ノイズクラスタリングにより算出した重心を可視化→処理時間がかかるためデータ数を減らして行う？
# ２．重心から領域を広げていく（同心円状に安全マージンの導入をしてみてもいいかも）
# ３．重心内の含有量を算出し、一定値以上となった場合広げるのをやめる
# ４．以上により三次元空間の判定領域を作成
# →同心円状の場合は、判定領域内かどうかは半径と点同士の距離を測定して算出が可能

# %%
# まず一つのクラスタに対する処理を記載する
"""
1．クラスタ中心と所属サンプルの距離を計算し最大距離を算出（やはりノイズがあるから四分位数などを使うといいかも）
2. 他クラスサンプルとの距離を求めていき、最小距離の更新をしていく（処理量を落とすために、クラスタ距離から絞るのあり2,3クラスまで？）
3. 最小距離（-margin）を半径とする球を作成し、その内部を判別領域とする
"""
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# 半径格納用
radius_class=np.zeros((10,))

# クラスタ中心
for i in range(class_num):
    print(class_names)
    # 同クラスの中で最も遠い距離を算出
    dis_same=calculate_distances(z_valid_np[y_valid_np==i], centroids[i])
    max_dis=np.max(dis_same)
    print(f"クラス{i}内の最大距離：{max_dis}")
    # 他クラスとの距離を求めていく
    # クラスタ同士の距離を計算
    main_centroid=centroids[i]
    sub_centroids=np.delete(centroids, i, axis=0)
    class_names_1=['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
    del class_names_1[i]
    dis_centroids=calculate_distances(sub_centroids, main_centroid)
    sorted_dis_centroids=np.argsort(dis_centroids)
    # 最小の2つの要素のインデックスを取得
    indices_of_min_values = sorted_dis_centroids[:2]
    selected_class_names = [class_names_1[i] for i in indices_of_min_values]
    print(class_names_1)
    print(f"クラス{i}との最小距離の2つの要素のインデックス:{selected_class_names}")
    # 取得したインデックス所属するサンプルと目的クラスタの距離を計算して最小の値を算出する（margin2の導入？）
    # 選択したクラス名に対応するclass_namesのインデックスを取得
    selected_indices = [class_names.index(class_name) for class_name in selected_class_names]

    # 取得したインデックスを使用してforループを実行
    minimum=float("inf")
    min_index=0
    for index in selected_indices:
        print(f"Index: {index}, Class Name: {class_names[index]}")
        dis_dif=calculate_distances(z_valid_np[y_valid_np==index], centroids[i])
        index_can=np.argmin(dis_dif)
        if dis_dif[index_can] < minimum:
            minimum=dis_dif[index_can]
            min_index=index_can
    print(f"クラス{i}の半径の値：{minimum}")
    radius_class[i]=minimum
# Out:
# ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# クラス0内の最大距離：3.6875843306730176
# ['Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# クラス0との最小距離の2つの要素のインデックス:['Shirt', 'Dress']
# Index: 6, Class Name: Shirt
# Index: 3, Class Name: Dress
# クラス0の半径の値：0.056549446233528575
# ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# クラス1内の最大距離：3.5859899183004607
# ['T-shirt/top', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# クラス1との最小距離の2つの要素のインデックス:['Dress', 'T-shirt/top']
# Index: 3, Class Name: Dress
# Index: 0, Class Name: T-shirt/top
# クラス1の半径の値：0.6932027925917245
# ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# クラス2内の最大距離：4.147290666950107
# ['T-shirt/top', 'Trouser', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# クラス2との最小距離の2つの要素のインデックス:['Coat', 'Shirt']
# Index: 4, Class Name: Coat
# Index: 6, Class Name: Shirt
# クラス2の半径の値：0.0781748501469546
# ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# クラス3内の最大距離：3.0321780573658232
# ['T-shirt/top', 'Trouser', 'Pullover', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# クラス3との最小距離の2つの要素のインデックス:['Shirt', 'T-shirt/top']
# Index: 6, Class Name: Shirt
# Index: 0, Class Name: T-shirt/top
# クラス3の半径の値：0.20611238446567903
# ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# クラス4内の最大距離：3.9884687027141785
# ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# クラス4との最小距離の2つの要素のインデックス:['Pullover', 'Shirt']
# Index: 2, Class Name: Pullover
# Index: 6, Class Name: Shirt
# クラス4の半径の値：0.10361534348857801
# ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# クラス5内の最大距離：3.9293465670681713
# ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# クラス5との最小距離の2つの要素のインデックス:['Sneaker', 'Ankle boot']
# Index: 7, Class Name: Sneaker
# Index: 9, Class Name: Ankle boot
# クラス5の半径の値：0.28845867332765807
# ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# クラス6内の最大距離：4.022073357539776
# ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Sneaker', 'Bag', 'Ankle boot']
# クラス6との最小距離の2つの要素のインデックス:['T-shirt/top', 'Pullover']
# Index: 0, Class Name: T-shirt/top
# Index: 2, Class Name: Pullover
# クラス6の半径の値：0.08968213538061495
# ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# クラス7内の最大距離：2.372326790464465
# ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Bag', 'Ankle boot']
# クラス7との最小距離の2つの要素のインデックス:['Sandal', 'Ankle boot']
# Index: 5, Class Name: Sandal
# Index: 9, Class Name: Ankle boot
# クラス7の半径の値：0.050497034732556074
# ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# クラス8内の最大距離：2.88494762856134
# ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Ankle boot']
# クラス8との最小距離の2つの要素のインデックス:['Shirt', 'Ankle boot']
# Index: 6, Class Name: Shirt
# Index: 9, Class Name: Ankle boot
# クラス8の半径の値：0.5499262372398328
# ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# クラス9内の最大距離：2.8191061022606796
# ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag']
# クラス9との最小距離の2つの要素のインデックス:['Sneaker', 'Sandal']
# Index: 7, Class Name: Sneaker
# Index: 5, Class Name: Sandal
# クラス9の半径の値：0.16384942099551814

# %%
# Step 2: Create random data for each class
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# Step 3: Create a figure and axis with a larger figsize
fig, ax = plt.subplots(figsize=(14, 10))  # Adjust the width and height as needed

data= [calculate_distances(z_valid_np[y_valid_np==i], centroids[i]) for i in range(10)]

# Step 4: Create boxplots
boxplot=plt.boxplot(data, vert=False)

# クラス名を設定
plt.yticks(range(1, 11), class_names)

# 外れ値の個数を表示
for i, flier in enumerate(boxplot['fliers']):
    y = flier.get_data()[1]
    num_outliers = len(y)
    plt.text(2.1, i + 1, f'Outliers: {num_outliers} /3000', va='center', fontsize=10, color="blue")

# グラフのタイトルと軸ラベルを設定
plt.title('Box Plot of 10 Classes with 3000 Data Points Each')
plt.xlabel('Data Values')

plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1400">

# %% [markdown]
# ドットプロット図

# %%
# %matplotlib notebook

fig, ax = plt.subplots(figsize=(14, 10))  # Adjust the width and height as needed

# クラス名と色のリスト
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
colors = ["blue","green","red","cyan","magenta","yellow","black",'purple','#a65628','#ff7f00']

for i in range(10):
    for j in range(10):
        dis_sub=calculate_distances(z_valid_np[y_valid_np==j], centroids[i])
        plt.scatter(dis_sub, np.ones_like(dis_sub) * (10-i), color=colors[j], label=class_names[i], s=0.5)

# クラス名を設定
plt.yticks(range(10, 0, -1), class_names)
plt.xlabel('Data Value')
plt.title('Dot Plot of One-Dimensional Data')
plt.grid(axis='x')  # x軸にグリッドを表示
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1400">

# %%
radius_class
radius_class_arbitary=[0.1, 0.25, 0.08, 0.3, 0.15, 0.5, 0.2, 0.4, 0.6, 0.8]
radius_class_arbitary=np.array(radius_class_arbitary)

# %%
# %matplotlib notebook
from pylab import rcParams
rcParams['figure.figsize'] = 10, 10


# 球体のパラメータ
radius = radius_class_arbitary
phi = np.linspace(0, np.pi, 15)  # 緯度角の範囲
theta = np.linspace(0, 2 * np.pi, 30)  # 経度角の範囲
phi, theta=np.meshgrid(phi, theta)

# figureを生成する
fig=plt.figure()
# axをfigureに設定する
ax = fig.add_subplot(111, projection='3d')

# 球体の座標を計算
for i in range(10):
    x = radius[i] * np.sin(phi) * np.cos(theta)+centroids[i, 0]
    y = radius[i] * np.sin(phi) * np.sin(theta)+centroids[i, 1]
    z = radius[i] * np.cos(phi)+centroids[i, 2]
    ax.scatter(centroids[i, 0], centroids[i, 1], centroids[i, 2], marker='*', color=colors[i], label=class_names[i], s=100, edgecolors="black")
    ax.plot_surface(x, y, z, color=colors[i], label=class_names[i], alpha=0.5)

    
ax.set_xlim([-2,2])
ax.set_ylim([-2,2])
ax.set_zlim([-2,2])
# ax.legend()  # 凡例の追加
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# %matplotlib notebook
from pylab import rcParams
rcParams['figure.figsize'] = 10, 10

# 球体のパラメータ
radius = radius_class
phi = np.linspace(0, np.pi, 15)  # 緯度角の範囲
theta = np.linspace(0, 2 * np.pi, 30)  # 経度角の範囲
phi, theta = np.meshgrid(phi, theta)

# figureを生成する
fig = plt.figure()
# axをfigureに設定する
ax = fig.add_subplot(111, projection='3d')

# 球体の座標を計算
for i in range(10):
    x = radius[i] * np.sin(phi) * np.cos(theta) + centroids[i, 0]
    y = radius[i] * np.sin(phi) * np.sin(theta) + centroids[i, 1]
    z = radius[i] * np.cos(phi) + centroids[i, 2]
    ax.plot_surface(x, y, z, color=colors[i], alpha=0.5)
    ax.scatter(centroids[i, 0], centroids[i, 1], centroids[i, 2], marker='*', color=colors[i], label=class_names[i], s=500, edgecolors="black")


# 凡例を手動で作成
legend_labels = []
for i in range(10):
    legend_labels.append(plt.Line2D([0], [0], marker='o', color=colors[i], markersize=5, label=class_names[i]))

# 星印の凡例も追加
legend_labels.append(plt.Line2D([0], [0], marker='*', color="black", markersize=10, label='Centroid'))

ax.set_xlim([-2, 2])
ax.set_ylim([-2, 2])
ax.set_zlim([-2, 2])
ax.legend(handles=legend_labels)  # 凡例の追加

plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


rcParams['figure.figsize'] = 10, 10

# 球体のパラメータ
radius = radius_class_arbitary
phi = np.linspace(0, np.pi, 15)  # 緯度角の範囲
theta = np.linspace(0, 2 * np.pi, 30)  # 経度角の範囲
phi, theta = np.meshgrid(phi, theta)

# クラス名
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# クラス数
class_num=len(class_names)
# 事前に定義された10色のリスト
colors = ["blue","green","red","cyan","magenta","yellow","black",'#f781bf','#a65628','#ff7f00']
# figureを生成する
plt.figure(figsize=(10, 10))
# axをfigureに設定する
ax = plt.subplot(111, projection='3d')
# クラスごとに色を分けてプロット
for i in range(class_num):    
    ax.scatter(z_valid_np[y_valid_np==i, 0], z_valid_np[y_valid_np==i, 1], z_valid_np[y_valid_np==i, 2], color=colors[i], label=class_names[i], alpha=0.02)

# 球体の座標を計算
for i in range(10):
    x = radius[i] * np.sin(phi) * np.cos(theta) + centroids[i, 0]
    y = radius[i] * np.sin(phi) * np.sin(theta) + centroids[i, 1]
    z = radius[i] * np.cos(phi) + centroids[i, 2]
    ax.plot_surface(x, y, z, color=colors[i], alpha=0.5, edgecolors="black")
    ax.scatter(centroids[i, 0], centroids[i, 1], centroids[i, 2], marker='*', color=colors[i], label=class_names[i], s=300, edgecolors="black")

    
# 凡例を手動で作成
legend_labels = []
for i in range(10):
    legend_labels.append(plt.Line2D([0], [0], marker='o', color=colors[i], markersize=5, label=class_names[i]))

# 星印の凡例も追加
legend_labels.append(plt.Line2D([0], [0], marker='*', color="black", markersize=10, label='Centroid'))

ax.set_xlim([-2, 2])
ax.set_ylim([-2, 2])
ax.set_zlim([-2, 2])
ax.legend(handles=legend_labels)  # 凡例の追加
plt.tight_layout()
plt.show()
# Out:
# <div id='fb15d0a4-03dd-406e-8eb0-27ade3d77b15'></div>

# %% [markdown]
# <font size="5">testデータで性能判定

# %% [markdown]
# 1. CNNから(3,)の出力を受け取る
# 2, 各クラスタとの距離を算出して最小のものを選択→半径以内かどうか判定（二十判定、判定がない場合に予測不可とする）

# %%
# モデル評価
model.eval()                                                      # 評価モード
with torch.no_grad():
    z_test = []
    y_test = []
    for X, y in test_loader:                                      # テスト用DataLoader
#         print(X)
        print(y)
        z_test.append(model.forward_once(X.to(device)))           # テストデータをモデルに通して出力ベクトルを得る
        y_test.append(y)                                          # ラベル（靴、シャツ）の代わりにラベルIDとして0～9の数代わり振られている
    z_test = torch.cat(z_test, dim=0)                             # 多次元torch.tensor要素のリストをtorch.tensor化
    y_test = torch.tensor(y_test)

# z_testとy_testをGPUに移動
z_test = z_test.to(device)
y_test = y_test.to(device)
# ndarrayに変換
z_test_np = z_test.to('cpu').detach().numpy().copy()
y_test_np = y_test.to('cpu').detach().numpy().copy()
print(z_test_np.shape)
print(y_test_np.shape)
# Out:
# tensor([9])
# tensor([2])
# tensor([1])
# tensor([1])
# tensor([6])
# tensor([1])
# tensor([4])
# tensor([6])
# tensor([5])
# tensor([7])
# tensor([4])
# tensor([5])
# tensor([7])
# tensor([3])
# tensor([4])
# tensor([1])
# tensor([2])
# tensor([4])
# tensor([8])
# tensor([0])
# tensor([2])
# tensor([5])
# tensor([7])
# tensor([9])
# tensor([1])
# tensor([4])
# tensor([6])
# tensor([0])
# tensor([9])
# tensor([3])
# tensor([8])
# tensor([8])
# tensor([3])
# tensor([3])
# tensor([8])
# tensor([0])
# tensor([7])
# tensor([5])
# tensor([7])
# tensor([9])
# tensor([6])
# tensor([1])
# tensor([3])
# tensor([7])
# tensor([6])
# tensor([7])
# tensor([2])
# tensor([1])
# tensor([2])
# tensor([2])
# tensor([4])
# tensor([4])
# tensor([5])
# tensor([8])
# tensor([2])
# tensor([2])
# tensor([8])
# tensor([4])
# tensor([8])
# tensor([0])
# tensor([7])
# tensor([7])
# tensor([8])
# tensor([5])
# tensor([1])
# tensor([1])
# tensor([2])
# tensor([3])
# tensor([9])
# tensor([8])
# tensor([7])
# tensor([0])
# tensor([2])
# tensor([6])
# tensor([2])
# tensor([3])
# tensor([1])
# tensor([2])
# tensor([8])
# tensor([4])
# tensor([1])
# tensor([8])
# tensor([5])
# tensor([9])
# tensor([5])
# tensor([0])
# tensor([3])
# tensor([2])
# tensor([0])
# tensor([6])
# tensor([5])
# tensor([3])
# tensor([6])
# tensor([7])
# tensor([1])
# tensor([8])
# tensor([0])
# tensor([1])
# tensor([4])
# tensor([2])
# tensor([3])
# tensor([6])
# tensor([7])
# tensor([2])
# tensor([7])
# tensor([8])
# tensor([5])
# tensor([9])
# tensor([9])
# tensor([4])
# tensor([2])
# tensor([5])
# tensor([7])
# tensor([0])
# tensor([5])
# tensor([2])
# tensor([8])
# tensor([6])
# tensor([7])
# tensor([8])
# tensor([0])
# tensor([0])
# tensor([9])
# tensor([9])
# tensor([3])
# tensor([0])
# tensor([8])
# tensor([4])
# tensor([1])
# tensor([5])
# tensor([4])
# tensor([1])
# tensor([9])
# tensor([1])
# tensor([8])
# tensor([6])
# tensor([2])
# tensor([1])
# tensor([2])
# tensor([5])
# tensor([1])
# tensor([0])
# tensor([0])
# tensor([0])
# tensor([1])
# tensor([6])
# tensor([1])
# tensor([6])
# tensor([2])
# tensor([2])
# tensor([4])
# tensor([4])
# tensor([1])
# tensor([4])
# tensor([5])
# tensor([0])
# tensor([4])
# tensor([7])
# tensor([9])
# tensor([3])
# tensor([7])
# tensor([2])
# tensor([3])
# tensor([9])
# tensor([0])
# tensor([9])
# tensor([4])
# tensor([7])
# tensor([4])
# tensor([2])
# tensor([0])
# tensor([5])
# tensor([2])
# tensor([1])
# tensor([2])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([9])
# tensor([1])
# tensor([0])
# tensor([9])
# tensor([3])
# tensor([6])
# tensor([7])
# tensor([9])
# tensor([9])
# tensor([4])
# tensor([4])
# tensor([7])
# tensor([1])
# tensor([2])
# tensor([1])
# tensor([6])
# tensor([3])
# tensor([2])
# tensor([8])
# tensor([3])
# tensor([6])
# tensor([1])
# tensor([1])
# tensor([0])
# tensor([2])
# tensor([9])
# tensor([2])
# tensor([4])
# tensor([0])
# tensor([7])
# tensor([9])
# tensor([8])
# tensor([4])
# tensor([1])
# tensor([8])
# tensor([4])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([6])
# tensor([7])
# tensor([2])
# tensor([8])
# tensor([5])
# tensor([2])
# tensor([0])
# tensor([7])
# tensor([7])
# tensor([6])
# tensor([2])
# tensor([7])
# tensor([0])
# tensor([7])
# tensor([8])
# tensor([9])
# tensor([2])
# tensor([9])
# tensor([0])
# tensor([5])
# tensor([1])
# tensor([4])
# tensor([4])
# tensor([5])
# tensor([6])
# tensor([9])
# tensor([2])
# tensor([6])
# tensor([8])
# tensor([6])
# tensor([4])
# tensor([2])
# tensor([2])
# tensor([9])
# tensor([7])
# tensor([6])
# tensor([5])
# tensor([5])
# tensor([2])
# tensor([8])
# tensor([5])
# tensor([2])
# tensor([3])
# tensor([0])
# tensor([4])
# tensor([8])
# tensor([0])
# tensor([0])
# tensor([6])
# tensor([3])
# tensor([8])
# tensor([9])
# tensor([6])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([2])
# tensor([3])
# tensor([0])
# tensor([8])
# tensor([3])
# tensor([7])
# tensor([4])
# tensor([0])
# tensor([1])
# tensor([6])
# tensor([3])
# tensor([0])
# tensor([6])
# tensor([6])
# tensor([7])
# tensor([5])
# tensor([4])
# tensor([5])
# tensor([9])
# tensor([5])
# tensor([6])
# tensor([5])
# tensor([5])
# tensor([1])
# tensor([9])
# tensor([8])
# tensor([8])
# tensor([3])
# tensor([3])
# tensor([6])
# tensor([8])
# tensor([0])
# tensor([0])
# tensor([2])
# tensor([9])
# tensor([7])
# tensor([7])
# tensor([1])
# tensor([3])
# tensor([6])
# tensor([4])
# tensor([2])
# tensor([4])
# tensor([9])
# tensor([1])
# tensor([6])
# tensor([4])
# tensor([8])
# tensor([2])
# tensor([6])
# tensor([5])
# tensor([4])
# tensor([6])
# tensor([7])
# tensor([7])
# tensor([7])
# tensor([3])
# tensor([3])
# tensor([7])
# tensor([0])
# tensor([7])
# tensor([1])
# tensor([3])
# tensor([7])
# tensor([2])
# tensor([2])
# tensor([3])
# tensor([4])
# tensor([0])
# tensor([3])
# tensor([1])
# tensor([6])
# tensor([1])
# tensor([9])
# tensor([4])
# tensor([9])
# tensor([9])
# tensor([1])
# tensor([7])
# tensor([8])
# tensor([3])
# tensor([6])
# tensor([0])
# tensor([2])
# tensor([4])
# tensor([8])
# tensor([0])
# tensor([1])
# tensor([2])
# tensor([2])
# tensor([4])
# tensor([4])
# tensor([7])
# tensor([3])
# tensor([2])
# tensor([2])
# tensor([5])
# tensor([0])
# tensor([7])
# tensor([9])
# tensor([4])
# tensor([0])
# tensor([9])
# tensor([3])
# tensor([9])
# tensor([4])
# tensor([2])
# tensor([5])
# tensor([0])
# tensor([2])
# tensor([3])
# tensor([5])
# tensor([8])
# tensor([1])
# tensor([6])
# tensor([2])
# tensor([6])
# tensor([6])
# tensor([4])
# tensor([9])
# tensor([5])
# tensor([2])
# tensor([0])
# tensor([4])
# tensor([6])
# tensor([1])
# tensor([2])
# tensor([0])
# tensor([9])
# tensor([7])
# tensor([0])
# tensor([4])
# tensor([4])
# tensor([6])
# tensor([6])
# tensor([2])
# tensor([1])
# tensor([0])
# tensor([6])
# tensor([7])
# tensor([2])
# tensor([9])
# tensor([4])
# tensor([2])
# tensor([1])
# tensor([5])
# tensor([4])
# tensor([5])
# tensor([3])
# tensor([8])
# tensor([5])
# tensor([8])
# tensor([4])
# tensor([4])
# tensor([8])
# tensor([9])
# tensor([8])
# tensor([6])
# tensor([2])
# tensor([4])
# tensor([4])
# tensor([2])
# tensor([4])
# tensor([1])
# tensor([6])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([9])
# tensor([8])
# tensor([8])
# tensor([6])
# tensor([5])
# tensor([3])
# tensor([1])
# tensor([9])
# tensor([5])
# tensor([3])
# tensor([3])
# tensor([0])
# tensor([1])
# tensor([0])
# tensor([2])
# tensor([9])
# tensor([2])
# tensor([0])
# tensor([6])
# tensor([3])
# tensor([4])
# tensor([2])
# tensor([0])
# tensor([0])
# tensor([3])
# tensor([3])
# tensor([8])
# tensor([2])
# tensor([8])
# tensor([9])
# tensor([4])
# tensor([0])
# tensor([7])
# tensor([6])
# tensor([4])
# tensor([4])
# tensor([9])
# tensor([2])
# tensor([9])
# tensor([5])
# tensor([9])
# tensor([3])
# tensor([7])
# tensor([5])
# tensor([7])
# tensor([8])
# tensor([1])
# tensor([0])
# tensor([0])
# tensor([3])
# tensor([4])
# tensor([8])
# tensor([9])
# tensor([7])
# tensor([9])
# tensor([1])
# tensor([2])
# tensor([7])
# tensor([0])
# tensor([2])
# tensor([0])
# tensor([5])
# tensor([7])
# tensor([1])
# tensor([8])
# tensor([2])
# tensor([2])
# tensor([2])
# tensor([2])
# tensor([4])
# tensor([2])
# tensor([6])
# tensor([1])
# tensor([9])
# tensor([8])
# tensor([5])
# tensor([1])
# tensor([9])
# tensor([1])
# tensor([2])
# tensor([8])
# tensor([3])
# tensor([8])
# tensor([9])
# tensor([2])
# tensor([4])
# tensor([2])
# tensor([8])
# tensor([8])
# tensor([2])
# tensor([0])
# tensor([5])
# tensor([8])
# tensor([8])
# tensor([5])
# tensor([3])
# tensor([9])
# tensor([4])
# tensor([3])
# tensor([4])
# tensor([4])
# tensor([5])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([2])
# tensor([0])
# tensor([6])
# tensor([9])
# tensor([6])
# tensor([1])
# tensor([5])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([9])
# tensor([3])
# tensor([4])
# tensor([5])
# tensor([3])
# tensor([6])
# tensor([6])
# tensor([6])
# tensor([4])
# tensor([6])
# tensor([0])
# tensor([5])
# tensor([8])
# tensor([3])
# tensor([3])
# tensor([4])
# tensor([6])
# tensor([7])
# tensor([7])
# tensor([8])
# tensor([9])
# tensor([0])
# tensor([3])
# tensor([8])
# tensor([7])
# tensor([6])
# tensor([7])
# tensor([9])
# tensor([3])
# tensor([4])
# tensor([6])
# tensor([6])
# tensor([5])
# tensor([0])
# tensor([1])
# tensor([1])
# tensor([5])
# tensor([9])
# tensor([4])
# tensor([6])
# tensor([5])
# tensor([7])
# tensor([8])
# tensor([1])
# tensor([2])
# tensor([9])
# tensor([7])
# tensor([7])
# tensor([1])
# tensor([0])
# tensor([9])
# tensor([3])
# tensor([2])
# tensor([9])
# tensor([0])
# tensor([7])
# tensor([6])
# tensor([8])
# tensor([2])
# tensor([7])
# tensor([0])
# tensor([2])
# tensor([3])
# tensor([8])
# tensor([2])
# tensor([2])
# tensor([6])
# tensor([9])
# tensor([3])
# tensor([0])
# tensor([7])
# tensor([8])
# tensor([6])
# tensor([2])
# tensor([9])
# tensor([4])
# tensor([2])
# tensor([6])
# tensor([6])
# tensor([8])
# tensor([0])
# tensor([4])
# tensor([4])
# tensor([4])
# tensor([7])
# tensor([5])
# tensor([8])
# tensor([4])
# tensor([9])
# tensor([1])
# tensor([0])
# tensor([5])
# tensor([4])
# tensor([4])
# tensor([4])
# tensor([0])
# tensor([0])
# tensor([4])
# tensor([5])
# tensor([6])
# tensor([0])
# tensor([4])
# tensor([5])
# tensor([4])
# tensor([1])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([6])
# tensor([4])
# tensor([3])
# tensor([8])
# tensor([2])
# tensor([8])
# tensor([2])
# tensor([7])
# tensor([0])
# tensor([4])
# tensor([0])
# tensor([8])
# tensor([5])
# tensor([0])
# tensor([8])
# tensor([2])
# tensor([9])
# tensor([0])
# tensor([8])
# tensor([9])
# tensor([6])
# tensor([4])
# tensor([2])
# tensor([9])
# tensor([3])
# tensor([4])
# tensor([5])
# tensor([0])
# tensor([9])
# tensor([5])
# tensor([3])
# tensor([6])
# tensor([6])
# tensor([8])
# tensor([3])
# tensor([3])
# tensor([8])
# tensor([1])
# tensor([4])
# tensor([0])
# tensor([9])
# tensor([7])
# tensor([9])
# tensor([4])
# tensor([8])
# tensor([9])
# tensor([1])
# tensor([6])
# tensor([7])
# tensor([3])
# tensor([0])
# tensor([2])
# tensor([6])
# tensor([7])
# tensor([1])
# tensor([0])
# tensor([0])
# tensor([8])
# tensor([5])
# tensor([2])
# tensor([6])
# tensor([6])
# tensor([6])
# tensor([4])
# tensor([1])
# tensor([5])
# tensor([9])
# tensor([0])
# tensor([2])
# tensor([1])
# tensor([6])
# tensor([5])
# tensor([0])
# tensor([0])
# tensor([3])
# tensor([3])
# tensor([3])
# tensor([8])
# tensor([1])
# tensor([1])
# tensor([8])
# tensor([5])
# tensor([7])
# tensor([7])
# tensor([8])
# tensor([7])
# tensor([2])
# tensor([0])
# tensor([7])
# tensor([3])
# tensor([8])
# tensor([0])
# tensor([9])
# tensor([7])
# tensor([6])
# tensor([1])
# tensor([2])
# tensor([6])
# tensor([4])
# tensor([8])
# tensor([0])
# tensor([6])
# tensor([3])
# tensor([6])
# tensor([8])
# tensor([4])
# tensor([0])
# tensor([8])
# tensor([9])
# tensor([2])
# tensor([4])
# tensor([5])
# tensor([9])
# tensor([1])
# tensor([4])
# tensor([4])
# tensor([9])
# tensor([2])
# tensor([1])
# tensor([7])
# tensor([9])
# tensor([5])
# tensor([8])
# tensor([1])
# tensor([7])
# tensor([7])
# tensor([1])
# tensor([1])
# tensor([1])
# tensor([6])
# tensor([9])
# tensor([5])
# tensor([3])
# tensor([8])
# tensor([4])
# tensor([2])
# tensor([7])
# tensor([4])
# tensor([8])
# tensor([3])
# tensor([2])
# tensor([4])
# tensor([4])
# tensor([7])
# tensor([1])
# tensor([4])
# tensor([9])
# tensor([3])
# tensor([5])
# tensor([8])
# tensor([5])
# tensor([4])
# tensor([7])
# tensor([2])
# tensor([8])
# tensor([5])
# tensor([9])
# tensor([3])
# tensor([3])
# tensor([6])
# tensor([7])
# tensor([1])
# tensor([7])
# tensor([3])
# tensor([5])
# tensor([4])
# tensor([4])
# tensor([5])
# tensor([8])
# tensor([3])
# tensor([7])
# tensor([1])
# tensor([2])
# tensor([6])
# tensor([1])
# tensor([9])
# tensor([8])
# tensor([2])
# tensor([7])
# tensor([1])
# tensor([3])
# tensor([7])
# tensor([5])
# tensor([9])
# tensor([9])
# tensor([1])
# tensor([8])
# tensor([5])
# tensor([7])
# tensor([1])
# tensor([9])
# tensor([8])
# tensor([1])
# tensor([0])
# tensor([0])
# tensor([6])
# tensor([1])
# tensor([7])
# tensor([1])
# tensor([1])
# tensor([5])
# tensor([7])
# tensor([1])
# tensor([5])
# tensor([3])
# tensor([3])
# tensor([1])
# tensor([1])
# tensor([4])
# tensor([9])
# tensor([4])
# tensor([3])
# tensor([7])
# tensor([7])
# tensor([0])
# tensor([8])
# tensor([9])
# tensor([9])
# tensor([6])
# tensor([1])
# tensor([3])
# tensor([0])
# tensor([0])
# tensor([5])
# tensor([9])
# tensor([0])
# tensor([5])
# tensor([5])
# tensor([1])
# tensor([5])
# tensor([7])
# tensor([8])
# tensor([7])
# tensor([5])
# tensor([3])
# tensor([6])
# tensor([0])
# tensor([0])
# tensor([6])
# tensor([0])
# tensor([5])
# tensor([5])
# tensor([0])
# tensor([9])
# tensor([3])
# tensor([7])
# tensor([8])
# tensor([6])
# tensor([8])
# tensor([3])
# tensor([7])
# tensor([0])
# tensor([7])
# tensor([8])
# tensor([0])
# tensor([3])
# tensor([3])
# tensor([9])
# tensor([0])
# tensor([6])
# tensor([9])
# tensor([8])
# tensor([7])
# tensor([5])
# tensor([5])
# tensor([6])
# tensor([5])
# tensor([6])
# tensor([7])
# tensor([5])
# tensor([3])
# tensor([5])
# tensor([9])
# tensor([6])
# tensor([8])
# tensor([6])
# tensor([6])
# tensor([9])
# tensor([6])
# tensor([7])
# tensor([7])
# tensor([6])
# tensor([5])
# tensor([3])
# tensor([9])
# tensor([9])
# tensor([8])
# tensor([8])
# tensor([3])
# tensor([6])
# tensor([6])
# tensor([3])
# tensor([3])
# tensor([5])
# tensor([9])
# tensor([3])
# tensor([7])
# tensor([7])
# tensor([3])
# tensor([5])
# tensor([5])
# tensor([6])
# tensor([5])
# tensor([9])
# tensor([6])
# tensor([3])
# tensor([7])
# tensor([5])
# tensor([9])
# tensor([8])
# tensor([8])
# tensor([9])
# tensor([9])
# tensor([7])
# tensor([3])
# tensor([8])
# tensor([7])
# tensor([6])
# tensor([5])
# tensor([3])
# tensor([9])
# tensor([3])
# tensor([5])
# tensor([5])
# tensor([7])
# tensor([5])
# tensor([3])
# tensor([3])
# tensor([5])
# tensor([7])
# tensor([8])
# tensor([5])
# tensor([5])
# tensor([8])
# tensor([5])
# tensor([5])
# (1000, 3)
# (1000,)

# %%
z_test_np
# Out:
# array([[ 2.9295557 , -0.74145657,  2.1242862 ],
#        [ 1.0063643 , -0.07813258, -2.9804864 ],
#        [-3.533734  ,  1.2906208 ,  0.26033965],
#        ...,
#        [ 1.5859826 ,  0.11268897,  0.09419998],
#        [ 0.38301203, -1.5298743 ,  2.188566  ],
#        [ 0.3695266 , -1.3146259 ,  1.9520857 ]], dtype=float32)

# %%
y_test_np
# Out:
# array([9, 2, 1, 1, 6, 1, 4, 6, 5, 7, 4, 5, 7, 3, 4, 1, 2, 4, 8, 0, 2, 5,
#        7, 9, 1, 4, 6, 0, 9, 3, 8, 8, 3, 3, 8, 0, 7, 5, 7, 9, 6, 1, 3, 7,
#        6, 7, 2, 1, 2, 2, 4, 4, 5, 8, 2, 2, 8, 4, 8, 0, 7, 7, 8, 5, 1, 1,
#        2, 3, 9, 8, 7, 0, 2, 6, 2, 3, 1, 2, 8, 4, 1, 8, 5, 9, 5, 0, 3, 2,
#        0, 6, 5, 3, 6, 7, 1, 8, 0, 1, 4, 2, 3, 6, 7, 2, 7, 8, 5, 9, 9, 4,
#        2, 5, 7, 0, 5, 2, 8, 6, 7, 8, 0, 0, 9, 9, 3, 0, 8, 4, 1, 5, 4, 1,
#        9, 1, 8, 6, 2, 1, 2, 5, 1, 0, 0, 0, 1, 6, 1, 6, 2, 2, 4, 4, 1, 4,
#        5, 0, 4, 7, 9, 3, 7, 2, 3, 9, 0, 9, 4, 7, 4, 2, 0, 5, 2, 1, 2, 1,
#        3, 0, 9, 1, 0, 9, 3, 6, 7, 9, 9, 4, 4, 7, 1, 2, 1, 6, 3, 2, 8, 3,
#        6, 1, 1, 0, 2, 9, 2, 4, 0, 7, 9, 8, 4, 1, 8, 4, 1, 3, 1, 6, 7, 2,
#        8, 5, 2, 0, 7, 7, 6, 2, 7, 0, 7, 8, 9, 2, 9, 0, 5, 1, 4, 4, 5, 6,
#        9, 2, 6, 8, 6, 4, 2, 2, 9, 7, 6, 5, 5, 2, 8, 5, 2, 3, 0, 4, 8, 0,
#        0, 6, 3, 8, 9, 6, 1, 3, 0, 2, 3, 0, 8, 3, 7, 4, 0, 1, 6, 3, 0, 6,
#        6, 7, 5, 4, 5, 9, 5, 6, 5, 5, 1, 9, 8, 8, 3, 3, 6, 8, 0, 0, 2, 9,
#        7, 7, 1, 3, 6, 4, 2, 4, 9, 1, 6, 4, 8, 2, 6, 5, 4, 6, 7, 7, 7, 3,
#        3, 7, 0, 7, 1, 3, 7, 2, 2, 3, 4, 0, 3, 1, 6, 1, 9, 4, 9, 9, 1, 7,
#        8, 3, 6, 0, 2, 4, 8, 0, 1, 2, 2, 4, 4, 7, 3, 2, 2, 5, 0, 7, 9, 4,
#        0, 9, 3, 9, 4, 2, 5, 0, 2, 3, 5, 8, 1, 6, 2, 6, 6, 4, 9, 5, 2, 0,
#        4, 6, 1, 2, 0, 9, 7, 0, 4, 4, 6, 6, 2, 1, 0, 6, 7, 2, 9, 4, 2, 1,
#        5, 4, 5, 3, 8, 5, 8, 4, 4, 8, 9, 8, 6, 2, 4, 4, 2, 4, 1, 6, 1, 3,
#        0, 9, 8, 8, 6, 5, 3, 1, 9, 5, 3, 3, 0, 1, 0, 2, 9, 2, 0, 6, 3, 4,
#        2, 0, 0, 3, 3, 8, 2, 8, 9, 4, 0, 7, 6, 4, 4, 9, 2, 9, 5, 9, 3, 7,
#        5, 7, 8, 1, 0, 0, 3, 4, 8, 9, 7, 9, 1, 2, 7, 0, 2, 0, 5, 7, 1, 8,
#        2, 2, 2, 2, 4, 2, 6, 1, 9, 8, 5, 1, 9, 1, 2, 8, 3, 8, 9, 2, 4, 2,
#        8, 8, 2, 0, 5, 8, 8, 5, 3, 9, 4, 3, 4, 4, 5, 1, 0, 1, 2, 0, 6, 9,
#        6, 1, 5, 1, 1, 1, 9, 3, 4, 5, 3, 6, 6, 6, 4, 6, 0, 5, 8, 3, 3, 4,
#        6, 7, 7, 8, 9, 0, 3, 8, 7, 6, 7, 9, 3, 4, 6, 6, 5, 0, 1, 1, 5, 9,
#        4, 6, 5, 7, 8, 1, 2, 9, 7, 7, 1, 0, 9, 3, 2, 9, 0, 7, 6, 8, 2, 7,
#        0, 2, 3, 8, 2, 2, 6, 9, 3, 0, 7, 8, 6, 2, 9, 4, 2, 6, 6, 8, 0, 4,
#        4, 4, 7, 5, 8, 4, 9, 1, 0, 5, 4, 4, 4, 0, 0, 4, 5, 6, 0, 4, 5, 4,
#        1, 3, 1, 1, 6, 4, 3, 8, 2, 8, 2, 7, 0, 4, 0, 8, 5, 0, 8, 2, 9, 0,
#        8, 9, 6, 4, 2, 9, 3, 4, 5, 0, 9, 5, 3, 6, 6, 8, 3, 3, 8, 1, 4, 0,
#        9, 7, 9, 4, 8, 9, 1, 6, 7, 3, 0, 2, 6, 7, 1, 0, 0, 8, 5, 2, 6, 6,
#        6, 4, 1, 5, 9, 0, 2, 1, 6, 5, 0, 0, 3, 3, 3, 8, 1, 1, 8, 5, 7, 7,
#        8, 7, 2, 0, 7, 3, 8, 0, 9, 7, 6, 1, 2, 6, 4, 8, 0, 6, 3, 6, 8, 4,
#        0, 8, 9, 2, 4, 5, 9, 1, 4, 4, 9, 2, 1, 7, 9, 5, 8, 1, 7, 7, 1, 1,
#        1, 6, 9, 5, 3, 8, 4, 2, 7, 4, 8, 3, 2, 4, 4, 7, 1, 4, 9, 3, 5, 8,
#        5, 4, 7, 2, 8, 5, 9, 3, 3, 6, 7, 1, 7, 3, 5, 4, 4, 5, 8, 3, 7, 1,
#        2, 6, 1, 9, 8, 2, 7, 1, 3, 7, 5, 9, 9, 1, 8, 5, 7, 1, 9, 8, 1, 0,
#        0, 6, 1, 7, 1, 1, 5, 7, 1, 5, 3, 3, 1, 1, 4, 9, 4, 3, 7, 7, 0, 8,
#        9, 9, 6, 1, 3, 0, 0, 5, 9, 0, 5, 5, 1, 5, 7, 8, 7, 5, 3, 6, 0, 0,
#        6, 0, 5, 5, 0, 9, 3, 7, 8, 6, 8, 3, 7, 0, 7, 8, 0, 3, 3, 9, 0, 6,
#        9, 8, 7, 5, 5, 6, 5, 6, 7, 5, 3, 5, 9, 6, 8, 6, 6, 9, 6, 7, 7, 6,
#        5, 3, 9, 9, 8, 8, 3, 6, 6, 3, 3, 5, 9, 3, 7, 7, 3, 5, 5, 6, 5, 9,
#        6, 3, 7, 5, 9, 8, 8, 9, 9, 7, 3, 8, 7, 6, 5, 3, 9, 3, 5, 5, 7, 5,
#        3, 3, 5, 7, 8, 5, 5, 8, 5, 5], dtype=int64)

# %%
# 134番目の画像を取得
index = 0
image = test_loader.dataset[index][0]
label = test_loader.dataset[index][1]

# 画像を28x28からより小さなサイズに変更
npimg = image.numpy()
print(type(npimg))
print(npimg.shape)
print(type(z_test_np[134]))
print(z_test_np[134].shape)
npimg = npimg.reshape((28, 28))

# 図のサイズを設定
plt.figure(figsize=(1, 1))

# 出力画像の解像度を上げるためにinterpolationパラメータを指定
plt.imshow(npimg, cmap='gray', interpolation='bilinear')

print('Label:', label)
# print(y_test_np[134])
plt.show()  # 図を表示
# Out:
# <class 'numpy.ndarray'>
# (1, 28, 28)
# <class 'numpy.ndarray'>
# (3,)
# <div id='efff4ce4-1b90-413b-9e66-44734ef06df3'></div>
# Label: 9

# %% [markdown]
# <font size="5">testデータに対して判定領域を作成

# %% [markdown]
# 判定領域作成のステップを以下に示す
# １．testデータを受け取る
# ２．testデータからの距離（球、立方体）の領域を獲得、その条件に合うデータを取ってきて、ラベルを確認する
# ３．ラベルから領域判定条件を設定する。し、解答を算出

# %%
# 格納用
data=[]
# level0がより左側のインデックスで、階層は上のインデックス
test_radius=[0.1, 0.2, 0.3, 1]
string_test_radius = [str(radius) for radius in test_radius for _ in range(3)]
# print(string_test_radius)
# level0
level0=string_test_radius
# 予測ラベル格納
predictions=np.zeros((z_test_np.shape[0],))
z_test_np
# 複製の作成
sub_y_test=y_test_np.copy()
# 割合パラメータ（50, 60, 70, 80, 90, 95）
para=60
# 四角形を作ってから、球状判定領域を作成
array=np.array(z_valid_np.shape)
percentage=np.empty(10)

label_ans = ["正解", "不正解", "解答不可"]
# test_radiusの値の数に応じてパターンを増やす
level1 = [label_ans[j] for i in range(len(test_radius)) for j in range(len(label_ans))]
indices = [level0, level1]
# print(indices)

# データの整理

for index in range(len(test_radius)):
    for l in range(z_test_np.shape[0]):
        # 四角形内か否かを判定
        array=(z_test_np[l]-test_radius[index] < z_valid_np) & (z_valid_np < z_test_np[l]+test_radius[index])
    #     print(array.shape)
        array1=array.all(axis=1)
    #     print(array1.shape)
    #     print(array1)
        array2=z_valid_np[array1]   
    #     print(array2.shape)
        # totalの計算
        total_elements=array2.shape[0]
        # labelの確認
        array3=y_valid_np[array1]
    #     print(type(array3))
        counts=np.bincount(array3, minlength=10)
        # 結果の表示
        for i in range(10):
            percentage[i] = (counts[i] / total_elements) * 100
    #         print(f"クラス {i} は {counts[i]} 回出現しました。割合は {percentage[i]:.2f}% です。")
    #     print("--------------------------------------------------------------------")
        # percentageがpara%を超えていればそのラベルを予測ラベルとし、そうでない場合は、他のラベルの割合比べたり、不可能ラベルとしたり
        #     条件分岐
        max_value = np.max(percentage)
    #     print(f"max_value:{max_value}")
        max_index = np.argmax(percentage)
    #     print(f"max_index:{max_index}")
        if para < max_value:
            predictions[l]=max_index
        else:
            predictions[l]=10 # 最小半径異常の距離の場合分類不可とする
        
    # クラスの数とクラスの名前を定義
    class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
    class_num = len(class_names)

    # ラベルごとの正解、不正解、解答不能のカウントを辞書として初期化
    label_counts = {class_names[label]: {"correct": 0, "incorrect": 0, "unanswerable": 0} for label in range(class_num)}

    # 予測と正解ラベルを比較し、各ラベルのカウントを更新
    for i in range(len(predictions)):
        prediction = predictions[i]
        label = y_test_np[i]

        if prediction == label:
            label_name = class_names[label]
            label_counts[label_name]["correct"] += 1
        elif prediction == 10:
            label_name = class_names[label]
            label_counts[label_name]["unanswerable"] += 1
            sub_y_test[i] = 10
        else:
            label_name = class_names[label]
            label_counts[label_name]["incorrect"] += 1
            
    # dataに格納（三周するはずその間に（10,3）を三回）
    label_2=["correct", "incorrect", "unanswerable"]
    arr=np.zeros(10)
    for j in range(len(label_2)):
        for i in range(len(class_names)):
            arr[i]=label_counts[class_names[i]][label_2[j]]
#             print(arr[i])
        arr2=arr.tolist()
        data.append(arr2)
    data2=np.array(data)
#     print(data2)

int_data=data2.astype(int)
column =  ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
print(column)
df = pd.DataFrame(int_data, index=indices, columns=column)
df
# Out:
# C:\Users\y9723\anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in longlong_scalars
# ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
#           T-shirt/top  Trouser  Pullover  Dress  Coat  Sandal  Shirt  Sneaker  \
# 0.1 正解             80       96        79     79    74      96     69       97
#     不正解            11        2        15      9    11       0     16        1
#     解答不可            9        2         6     12    15       4     15        2
# 0.2 正解             82       98        79     83    79     100     70       96
#     不正解             9        1        14      8    10       0     17        2
#     解答不可            9        1         7      9    11       0     13        2
# 0.3 正解             83       98        80     84    81      99     70       96
#     不正解            11        1        15      7    10       0     19        2
#     解答不可            6        1         5      9     9       1     11        2
# 1   正解             82       99        70     85    68     100     37       97
#     不正解             8        1         7      6     6       0     12        2
#     解答不可           10        0        23      9    26       0     51        1
#
#           Bag  Ankle boot
# 0.1 正解     93          96
#     不正解     0           4
#     解答不可    7           0
# 0.2 正解     97          95
#     不正解     0           4
#     解答不可    3           1
# 0.3 正解     97          95
#     不正解     1           4
#     解答不可    2           1
# 1   正解     97          95
#     不正解     1           3
#     解答不可    2           2

# %% [markdown]
# 不正解を出した解答を確認

# %%
# 格納用
data=[]
uncorrect_data=[]
# level0がより左側のインデックスで、階層は上のインデックス
test_radius=[0.2]
string_test_radius = [str(radius) for radius in test_radius for _ in range(3)]
# print(string_test_radius)
# level0
level0=string_test_radius
# 予測ラベル格納
predictions=np.zeros((z_test_np.shape[0],))
z_test_np
# 複製の作成
sub_y_test=y_test_np.copy()
# 割合パラメータ（50, 60, 70, 80, 90, 95）
para=60
# 四角形を作ってから、球状判定領域を作成
array=np.array(z_valid_np.shape)
percentage=np.empty(10)

label_ans = ["正解", "不正解", "解答不可"]
# test_radiusの値の数に応じてパターンを増やす
level1 = [label_ans[j] for i in range(len(test_radius)) for j in range(len(label_ans))]
indices = [level0, level1]
# print(indices)

# データの整理

for index in range(1):
    for l in range(z_test_np.shape[0]):
        # 四角形内か否かを判定
        array=(z_test_np[l]-test_radius[index] < z_valid_np) & (z_valid_np < z_test_np[l]+test_radius[index])
    #     print(array.shape)
        array1=array.all(axis=1)
    #     print(array1.shape)
    #     print(array1)
        array2=z_valid_np[array1]   
    #     print(array2.shape)
        # totalの計算
        total_elements=array2.shape[0]
        # labelの確認
        array3=y_valid_np[array1]
    #     print(type(array3))
        counts=np.bincount(array3, minlength=10)
        # 結果の表示
        for i in range(10):
            percentage[i] = (counts[i] / total_elements) * 100
#             print(f"クラス {i} は {counts[i]} 回出現しました。割合は {percentage[i]:.2f}% です。")
#         print("--------------------------------------------------------------------")
        # percentageがpara%を超えていればそのラベルを予測ラベルとし、そうでない場合は、他のラベルの割合比べたり、不可能ラベルとしたり
        #     条件分岐
        max_value = np.max(percentage)
#         print(f"max_value:{max_value}")
        max_index = np.argmax(percentage)
#         print(f"max_index:{max_index}")
        if para < max_value:
            predictions[l]=max_index
        else:
            predictions[l]=10 # 最小半径異常の距離の場合分類不可とする
        
    # クラスの数とクラスの名前を定義
    class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
    class_num = len(class_names)

    # ラベルごとの正解、不正解、解答不能のカウントを辞書として初期化
    label_counts = {class_names[label]: {"correct": 0, "incorrect": 0, "unanswerable": 0} for label in range(class_num)}

    # 予測と正解ラベルを比較し、各ラベルのカウントを更新
    for i in range(len(predictions)):
        prediction = predictions[i]
        label = y_test_np[i]

        if prediction == label:
            label_name = class_names[label]
            label_counts[label_name]["correct"] += 1
        elif prediction == 10:
            label_name = class_names[label]
            label_counts[label_name]["unanswerable"] += 1
            sub_y_test[i] = 10
        else:
            label_name = class_names[label]
            label_counts[label_name]["incorrect"] += 1
            # 不正解を見たい
            uncorrect_data.append(i)
    print(uncorrect_data)
    print(len(uncorrect_data))
            
    # dataに格納（三周するはずその間に（10,3）を三回）
    label_2=["correct", "incorrect", "unanswerable"]
    arr=np.zeros(10)
    for j in range(len(label_2)):
        for i in range(len(class_names)):
            arr[i]=label_counts[class_names[i]][label_2[j]]
#             print(arr[i])
        arr2=arr.tolist()
        data.append(arr2)
    data2=np.array(data)
#     print(data2)

int_data=data2.astype(int)
column =  ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
print(column)
df = pd.DataFrame(int_data, index=indices, columns=column)
df
# Out:
# C:\Users\y9723\anaconda3\lib\site-packages\ipykernel_launcher.py:47: RuntimeWarning: invalid value encountered in longlong_scalars
# [12, 23, 25, 40, 42, 43, 49, 51, 66, 67, 68, 74, 89, 98, 141, 147, 153, 155, 166, 222, 239, 241, 244, 248, 316, 325, 332, 344, 359, 361, 378, 381, 382, 396, 404, 413, 441, 444, 452, 454, 457, 460, 525, 565, 569, 639, 664, 670, 681, 684, 688, 699, 711, 715, 732, 760, 787, 859, 911, 922, 934, 937, 942, 947, 981]
# 65
# ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
#           T-shirt/top  Trouser  Pullover  Dress  Coat  Sandal  Shirt  Sneaker  \
# 0.2 正解             82       98        79     83    79     100     70       96
#     不正解             9        1        14      8    10       0     17        2
#     解答不可            9        1         7      9    11       0     13        2
#
#           Bag  Ankle boot
# 0.2 正解     97          95
#     不正解     0           4
#     解答不可    3           1

# %%
data=[]
# level0がより左側のインデックスで、階層は上のインデックス
test_radius=[0.2]
string_test_radius = [str(radius) for radius in test_radius for _ in range(3)]
# print(string_test_radius)
# level0
level0=string_test_radius
# 予測ラベル格納
# predictions=np.zeros((z_test_np.shape[0],))
z_test_np
# 複製の作成
sub_y_test=y_test_np.copy()
# 割合パラメータ（50, 60, 70, 80, 90, 95）
para=80
# 四角形を作ってから、球状判定領域を作成
array=np.array(z_valid_np.shape)
percentage=np.empty(10)

label_ans = ["正解", "不正解", "解答不可"]
# test_radiusの値の数に応じてパターンを増やす
level1 = [label_ans[j] for i in range(len(test_radius)) for j in range(len(label_ans))]
indices = [level0, level1]
# print(indices)

# データの整理

for index in range(1):
    for l in uncorrect_data:
        # 四角形内か否かを判定
        array=(z_test_np[l]-test_radius[index] < z_valid_np) & (z_valid_np < z_test_np[l]+test_radius[index])
    #     print(array.shape)
        array1=array.all(axis=1)
    #     print(array1.shape)
    #     print(array1)
        array2=z_valid_np[array1]   
        print(array2.shape)
        # totalの計算
        total_elements=array2.shape[0]
        # labelの確認
        array3=y_valid_np[array1]
    #     print(type(array3))
        counts=np.bincount(array3, minlength=10)
        # 結果の表示
        for i in range(10):
            percentage[i] = (counts[i] / total_elements) * 100
            print(f"クラス {i} は {counts[i]} 回出現しました。割合は {percentage[i]:.2f}% です。")
        print("--------------------------------------------------------------------")
        # percentageがpara%を超えていればそのラベルを予測ラベルとし、そうでない場合は、他のラベルの割合比べたり、不可能ラベルとしたり
        #     条件分岐
        max_value = np.max(percentage)
        print(f"max_value:{max_value}")
        max_index = np.argmax(percentage)
        print(f"max_index:{max_index}")
        print(f"解答は{y_test_np[l]}となる")
        print(f"インデックスは{l}")
# Out:
# (2, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 0 回出現しました。割合は 0.00% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 2 回出現しました。割合は 100.00% です。
# クラス 6 は 0 回出現しました。割合は 0.00% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:100.0
# max_index:5
# 解答は7となる
# インデックスは12
# (59, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 0 回出現しました。割合は 0.00% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 58 回出現しました。割合は 98.31% です。
# クラス 6 は 0 回出現しました。割合は 0.00% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 1 回出現しました。割合は 1.69% です。
# --------------------------------------------------------------------
# max_value:98.30508474576271
# max_index:5
# 解答は9となる
# インデックスは23
# (58, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 44 回出現しました。割合は 75.86% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 12 回出現しました。割合は 20.69% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 2 回出現しました。割合は 3.45% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:75.86206896551724
# max_index:2
# 解答は4となる
# インデックスは25
# (742, 3)
# クラス 0 は 618 回出現しました。割合は 83.29% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 1 回出現しました。割合は 0.13% です。
# クラス 3 は 2 回出現しました。割合は 0.27% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 121 回出現しました。割合は 16.31% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:83.28840970350404
# max_index:0
# 解答は6となる
# インデックスは40
# (240, 3)
# クラス 0 は 3 回出現しました。割合は 1.25% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 3 回出現しました。割合は 1.25% です。
# クラス 3 は 1 回出現しました。割合は 0.42% です。
# クラス 4 は 5 回出現しました。割合は 2.08% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 228 回出現しました。割合は 95.00% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:95.0
# max_index:6
# 解答は3となる
# インデックスは42
# (523, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 0 回出現しました。割合は 0.00% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 0 回出現しました。割合は 0.00% です。
# クラス 7 は 6 回出現しました。割合は 1.15% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 517 回出現しました。割合は 98.85% です。
# --------------------------------------------------------------------
# max_value:98.8527724665392
# max_index:9
# 解答は7となる
# インデックスは43
# (207, 3)
# クラス 0 は 2 回出現しました。割合は 0.97% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 34 回出現しました。割合は 16.43% です。
# クラス 3 は 1 回出現しました。割合は 0.48% です。
# クラス 4 は 7 回出現しました。割合は 3.38% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 163 回出現しました。割合は 78.74% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:78.74396135265701
# max_index:6
# 解答は2となる
# インデックスは49
# (204, 3)
# クラス 0 は 2 回出現しました。割合は 0.98% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 140 回出現しました。割合は 68.63% です。
# クラス 3 は 1 回出現しました。割合は 0.49% です。
# クラス 4 は 29 回出現しました。割合は 14.22% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 32 回出現しました。割合は 15.69% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:68.62745098039215
# max_index:2
# 解答は4となる
# インデックスは51
# (96, 3)
# クラス 0 は 23 回出現しました。割合は 23.96% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 0 回出現しました。割合は 0.00% です。
# クラス 3 は 1 回出現しました。割合は 1.04% です。
# クラス 4 は 1 回出現しました。割合は 1.04% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 71 回出現しました。割合は 73.96% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:73.95833333333334
# max_index:6
# 解答は2となる
# インデックスは66
# (37, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 1 回出現しました。割合は 2.70% です。
# クラス 3 は 9 回出現しました。割合は 24.32% です。
# クラス 4 は 25 回出現しました。割合は 67.57% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 2 回出現しました。割合は 5.41% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:67.56756756756756
# max_index:4
# 解答は3となる
# インデックスは67
# (2614, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 0 回出現しました。割合は 0.00% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 1 回出現しました。割合は 0.04% です。
# クラス 6 は 0 回出現しました。割合は 0.00% です。
# クラス 7 は 2610 回出現しました。割合は 99.85% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 3 回出現しました。割合は 0.11% です。
# --------------------------------------------------------------------
# max_value:99.84697781178271
# max_index:7
# 解答は9となる
# インデックスは68
# (161, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 27 回出現しました。割合は 16.77% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 128 回出現しました。割合は 79.50% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 5 回出現しました。割合は 3.11% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 1 回出現しました。割合は 0.62% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:79.5031055900621
# max_index:4
# 解答は2となる
# インデックスは74
# (70, 3)
# クラス 0 は 2 回出現しました。割合は 2.86% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 60 回出現しました。割合は 85.71% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 1 回出現しました。割合は 1.43% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 7 回出現しました。割合は 10.00% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:85.71428571428571
# max_index:2
# 解答は6となる
# インデックスは89
# (967, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 929 回出現しました。割合は 96.07% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 12 回出現しました。割合は 1.24% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 25 回出現しました。割合は 2.59% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 1 回出現しました。割合は 0.10% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:96.07032057911064
# max_index:2
# 解答は4となる
# インデックスは98
# (82, 3)
# クラス 0 は 2 回出現しました。割合は 2.44% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 0 回出現しました。割合は 0.00% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 80 回出現しました。割合は 97.56% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:97.5609756097561
# max_index:6
# 解答は0となる
# インデックスは141
# (2105, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 0 回出現しました。割合は 0.00% です。
# クラス 3 は 2103 回出現しました。割合は 99.90% です。
# クラス 4 は 2 回出現しました。割合は 0.10% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 0 回出現しました。割合は 0.00% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:99.90498812351544
# max_index:3
# 解答は6となる
# インデックスは147
# (21, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 0 回出現しました。割合は 0.00% です。
# クラス 3 は 17 回出現しました。割合は 80.95% です。
# クラス 4 は 3 回出現しました。割合は 14.29% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 1 回出現しました。割合は 4.76% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:80.95238095238095
# max_index:3
# 解答は4となる
# インデックスは153
# (144, 3)
# クラス 0 は 5 回出現しました。割合は 3.47% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 18 回出現しました。割合は 12.50% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 1 回出現しました。割合は 0.69% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 120 回出現しました。割合は 83.33% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:83.33333333333334
# max_index:6
# 解答は0となる
# インデックスは155
# (321, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 274 回出現しました。割合は 85.36% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 30 回出現しました。割合は 9.35% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 17 回出現しました。割合は 5.30% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:85.35825545171339
# max_index:2
# 解答は4となる
# インデックスは166
# (869, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 3 回出現しました。割合は 0.35% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 864 回出現しました。割合は 99.42% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 2 回出現しました。割合は 0.23% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:99.42462600690449
# max_index:4
# 解答は2となる
# インデックスは222
# (219, 3)
# クラス 0 は 3 回出現しました。割合は 1.37% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 147 回出現しました。割合は 67.12% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 12 回出現しました。割合は 5.48% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 57 回出現しました。割合は 26.03% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:67.12328767123287
# max_index:2
# 解答は4となる
# インデックスは239
# (507, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 4 回出現しました。割合は 0.79% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 500 回出現しました。割合は 98.62% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 3 回出現しました。割合は 0.59% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:98.61932938856016
# max_index:4
# 解答は6となる
# インデックスは241
# (406, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 401 回出現しました。割合は 98.77% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 4 回出現しました。割合は 0.99% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 1 回出現しました。割合は 0.25% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:98.76847290640394
# max_index:2
# 解答は6となる
# インデックスは244
# (58, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 3 回出現しました。割合は 5.17% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 1 回出現しました。割合は 1.72% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 54 回出現しました。割合は 93.10% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:93.10344827586206
# max_index:6
# 解答は2となる
# インデックスは248
# (17, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 0 回出現しました。割合は 0.00% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 0 回出現しました。割合は 0.00% です。
# クラス 7 は 13 回出現しました。割合は 76.47% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 4 回出現しました。割合は 23.53% です。
# --------------------------------------------------------------------
# max_value:76.47058823529412
# max_index:7
# 解答は9となる
# インデックスは316
# (84, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 80 回出現しました。割合は 95.24% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 4 回出現しました。割合は 4.76% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:95.23809523809523
# max_index:2
# 解答は6となる
# インデックスは325
# (1082, 3)
# クラス 0 は 7 回出現しました。割合は 0.65% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 6 回出現しました。割合は 0.55% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 6 回出現しました。割合は 0.55% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 1063 回出現しました。割合は 98.24% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:98.24399260628466
# max_index:6
# 解答は0となる
# インデックスは332
# (1892, 3)
# クラス 0 は 1828 回出現しました。割合は 96.62% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 3 回出現しました。割合は 0.16% です。
# クラス 3 は 2 回出現しました。割合は 0.11% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 59 回出現しました。割合は 3.12% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:96.61733615221986
# max_index:0
# 解答は6となる
# インデックスは344
# (9, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 0 回出現しました。割合は 0.00% です。
# クラス 3 は 1 回出現しました。割合は 11.11% です。
# クラス 4 は 1 回出現しました。割合は 11.11% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 7 回出現しました。割合は 77.78% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:77.77777777777779
# max_index:6
# 解答は0となる
# インデックスは359
# (681, 3)
# クラス 0 は 2 回出現しました。割合は 0.29% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 12 回出現しました。割合は 1.76% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 3 回出現しました。割合は 0.44% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 664 回出現しました。割合は 97.50% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:97.50367107195301
# max_index:6
# 解答は2となる
# インデックスは361
# (1, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 0 回出現しました。割合は 0.00% です。
# クラス 3 は 1 回出現しました。割合は 100.00% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 0 回出現しました。割合は 0.00% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:100.0
# max_index:3
# 解答は4となる
# インデックスは378
# (138, 3)
# クラス 0 は 4 回出現しました。割合は 2.90% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 1 回出現しました。割合は 0.72% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 133 回出現しました。割合は 96.38% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:96.37681159420289
# max_index:6
# 解答は0となる
# インデックスは381
# (1876, 3)
# クラス 0 は 1816 回出現しました。割合は 96.80% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 3 回出現しました。割合は 0.16% です。
# クラス 3 は 1 回出現しました。割合は 0.05% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 56 回出現しました。割合は 2.99% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:96.80170575692964
# max_index:0
# 解答は2となる
# インデックスは382
# (23, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 1 回出現しました。割合は 4.35% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 8 回出現しました。割合は 34.78% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 14 回出現しました。割合は 60.87% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:60.86956521739131
# max_index:6
# 解答は4となる
# インデックスは396
# (81, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 0 回出現しました。割合は 0.00% です。
# クラス 3 は 74 回出現しました。割合は 91.36% です。
# クラス 4 は 7 回出現しました。割合は 8.64% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 0 回出現しました。割合は 0.00% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:91.35802469135803
# max_index:3
# 解答は4となる
# インデックスは404
# (174, 3)
# クラス 0 は 3 回出現しました。割合は 1.72% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 11 回出現しました。割合は 6.32% です。
# クラス 3 は 1 回出現しました。割合は 0.57% です。
# クラス 4 は 9 回出現しました。割合は 5.17% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 150 回出現しました。割合は 86.21% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:86.20689655172413
# max_index:6
# 解答は2となる
# インデックスは413
# (1858, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 0 回出現しました。割合は 0.00% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 1 回出現しました。割合は 0.05% です。
# クラス 6 は 0 回出現しました。割合は 0.00% です。
# クラス 7 は 1856 回出現しました。割合は 99.89% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 1 回出現しました。割合は 0.05% です。
# --------------------------------------------------------------------
# max_value:99.89235737351991
# max_index:7
# 解答は9となる
# インデックスは441
# (445, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 0 回出現しました。割合は 0.00% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 444 回出現しました。割合は 99.78% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 1 回出現しました。割合は 0.22% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:99.7752808988764
# max_index:4
# 解答は6となる
# インデックスは444
# (545, 3)
# クラス 0 は 63 回出現しました。割合は 11.56% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 2 回出現しました。割合は 0.37% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 480 回出現しました。割合は 88.07% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:88.07339449541286
# max_index:6
# 解答は0となる
# インデックスは452
# (159, 3)
# クラス 0 は 11 回出現しました。割合は 6.92% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 1 回出現しました。割合は 0.63% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 147 回出現しました。割合は 92.45% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:92.45283018867924
# max_index:6
# 解答は0となる
# インデックスは454
# (245, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 42 回出現しました。割合は 17.14% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 192 回出現しました。割合は 78.37% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 11 回出現しました。割合は 4.49% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:78.36734693877551
# max_index:4
# 解答は2となる
# インデックスは457
# (124, 3)
# クラス 0 は 15 回出現しました。割合は 12.10% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 1 回出現しました。割合は 0.81% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 108 回出現しました。割合は 87.10% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:87.09677419354838
# max_index:6
# 解答は3となる
# インデックスは460
# (1203, 3)
# クラス 0 は 1 回出現しました。割合は 0.08% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 9 回出現しました。割合は 0.75% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 1183 回出現しました。割合は 98.34% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 10 回出現しました。割合は 0.83% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:98.33748960931005
# max_index:4
# 解答は2となる
# インデックスは525
# (454, 3)
# クラス 0 は 285 回出現しました。割合は 62.78% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 1 回出現しました。割合は 0.22% です。
# クラス 3 は 1 回出現しました。割合は 0.22% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 167 回出現しました。割合は 36.78% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:62.77533039647577
# max_index:0
# 解答は6となる
# インデックスは565
# (12, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 0 回出現しました。割合は 0.00% です。
# クラス 3 は 1 回出現しました。割合は 8.33% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 10 回出現しました。割合は 83.33% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 1 回出現しました。割合は 8.33% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:83.33333333333334
# max_index:6
# 解答は3となる
# インデックスは569
# (508, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 500 回出現しました。割合は 98.43% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 4 回出現しました。割合は 0.79% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 4 回出現しました。割合は 0.79% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:98.4251968503937
# max_index:2
# 解答は4となる
# インデックスは639
# (122, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 28 回出現しました。割合は 22.95% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 78 回出現しました。割合は 63.93% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 16 回出現しました。割合は 13.11% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:63.934426229508205
# max_index:4
# 解答は6となる
# インデックスは664
# (436, 3)
# クラス 0 は 128 回出現しました。割合は 29.36% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 3 回出現しました。割合は 0.69% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 305 回出現しました。割合は 69.95% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:69.95412844036697
# max_index:6
# 解答は2となる
# インデックスは670
# (11, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 1 回出現しました。割合は 9.09% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 9 回出現しました。割合は 81.82% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 1 回出現しました。割合は 9.09% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:81.81818181818183
# max_index:6
# 解答は0となる
# インデックスは681
# (1473, 3)
# クラス 0 は 1386 回出現しました。割合は 94.09% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 3 回出現しました。割合は 0.20% です。
# クラス 3 は 1 回出現しました。割合は 0.07% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 83 回出現しました。割合は 5.63% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:94.09368635437882
# max_index:0
# 解答は6となる
# インデックスは684
# (39, 3)
# クラス 0 は 1 回出現しました。割合は 2.56% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 2 回出現しました。割合は 5.13% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 2 回出現しました。割合は 5.13% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 34 回出現しました。割合は 87.18% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:87.17948717948718
# max_index:6
# 解答は3となる
# インデックスは688
# (122, 3)
# クラス 0 は 38 回出現しました。割合は 31.15% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 1 回出現しました。割合は 0.82% です。
# クラス 3 は 2 回出現しました。割合は 1.64% です。
# クラス 4 は 1 回出現しました。割合は 0.82% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 80 回出現しました。割合は 65.57% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:65.57377049180327
# max_index:6
# 解答は3となる
# インデックスは699
# (1291, 3)
# クラス 0 は 1 回出現しました。割合は 0.08% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 1 回出現しました。割合は 0.08% です。
# クラス 3 は 1284 回出現しました。割合は 99.46% です。
# クラス 4 は 2 回出現しました。割合は 0.15% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 3 回出現しました。割合は 0.23% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:99.4577846630519
# max_index:3
# 解答は6となる
# インデックスは711
# (859, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 13 回出現しました。割合は 1.51% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 834 回出現しました。割合は 97.09% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 12 回出現しました。割合は 1.40% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:97.08963911525029
# max_index:4
# 解答は2となる
# インデックスは715
# (312, 3)
# クラス 0 は 291 回出現しました。割合は 93.27% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 0 回出現しました。割合は 0.00% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 21 回出現しました。割合は 6.73% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:93.26923076923077
# max_index:0
# 解答は2となる
# インデックスは732
# (262, 3)
# クラス 0 は 9 回出現しました。割合は 3.44% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 1 回出現しました。割合は 0.38% です。
# クラス 3 は 1 回出現しました。割合は 0.38% です。
# クラス 4 は 7 回出現しました。割合は 2.67% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 244 回出現しました。割合は 93.13% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:93.12977099236642
# max_index:6
# 解答は2となる
# インデックスは760
# (741, 3)
# クラス 0 は 1 回出現しました。割合は 0.13% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 0 回出現しました。割合は 0.00% です。
# クラス 3 は 740 回出現しました。割合は 99.87% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 0 回出現しました。割合は 0.00% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:99.86504723346829
# max_index:3
# 解答は1となる
# インデックスは787
# (470, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 437 回出現しました。割合は 92.98% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 20 回出現しました。割合は 4.26% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 13 回出現しました。割合は 2.77% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:92.97872340425532
# max_index:2
# 解答は6となる
# インデックスは859
# (196, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 25 回出現しました。割合は 12.76% です。
# クラス 3 は 1 回出現しました。割合は 0.51% です。
# クラス 4 は 145 回出現しました。割合は 73.98% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 25 回出現しました。割合は 12.76% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:73.9795918367347
# max_index:4
# 解答は6となる
# インデックスは911
# (53, 3)
# クラス 0 は 3 回出現しました。割合は 5.66% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 6 回出現しました。割合は 11.32% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 44 回出現しました。割合は 83.02% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:83.01886792452831
# max_index:6
# 解答は0となる
# インデックスは922
# (11, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 1 回出現しました。割合は 9.09% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 2 回出現しました。割合は 18.18% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 8 回出現しました。割合は 72.73% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:72.72727272727273
# max_index:6
# 解答は3となる
# インデックスは934
# (184, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 34 回出現しました。割合は 18.48% です。
# クラス 3 は 1 回出現しました。割合は 0.54% です。
# クラス 4 は 128 回出現しました。割合は 69.57% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 21 回出現しました。割合は 11.41% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:69.56521739130434
# max_index:4
# 解答は6となる
# インデックスは937
# (303, 3)
# クラス 0 は 230 回出現しました。割合は 75.91% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 2 回出現しました。割合は 0.66% です。
# クラス 3 は 1 回出現しました。割合は 0.33% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 70 回出現しました。割合は 23.10% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:75.9075907590759
# max_index:0
# 解答は6となる
# インデックスは942
# (1480, 3)
# クラス 0 は 1429 回出現しました。割合は 96.55% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 5 回出現しました。割合は 0.34% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 46 回出現しました。割合は 3.11% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:96.55405405405405
# max_index:0
# 解答は3となる
# インデックスは947
# (61, 3)
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 13 回出現しました。割合は 21.31% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 48 回出現しました。割合は 78.69% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 0 回出現しました。割合は 0.00% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:78.68852459016394
# max_index:4
# 解答は6となる
# インデックスは981

# %% [markdown]
# 不正解の画像を出力したい
# [12, 23, 25, 40, 42, 43, 49, 51, 66, 67, 68, 74, 89, 98, 141, 147, 153, 155, 166, 222, 239, 241, 244, 248, 316, 325, 332, 344, 359, 361, 378, 381, 382, 396, 404, 413, 441, 444, 452, 454, 457, 460, 525, 565, 569, 639, 664, 670, 681, 684, 688, 699, 711, 715, 732, 760, 787, 859, 911, 922, 934, 937, 942, 947, 981]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the list of indices
indices = [404, 413, 441, 444, 452, 454, 457, 460, 525, 565, 569, 639, 664, 670, 681, 684, 688, 699, 711, 715, 732, 760, 787, 859, 911, 922, 934, 937, 942, 947, 981]

# Assuming you have defined test_loader and z_test_np earlier in your code

# Loop through the indices and display the images
for index in indices:
    image = test_loader.dataset[index][0]
    label = test_loader.dataset[index][1]

    # Convert the image to a numpy array
    npimg = image.numpy()
    npimg = npimg.reshape((28, 28))

    # Set the figure size
    plt.figure(figsize=(1, 1))

    # Increase the resolution of the output image with interpolation
    plt.imshow(npimg, cmap='gray', interpolation='bilinear')
    print('インデックス：', index)
    print('予測：', predictions[index])
    print('Label:', label)
    plt.show()  # Display the image

# This loop will display the images at the specified indices one by one.
# Out:
# <div id='3752af3e-bf68-4fbd-9dab-99ae39446c9e'></div>
# インデックス： 404
# 予測： 3.0
# Label: 4
# <div id='d26d8d61-8590-4c84-a08c-78217ead305c'></div>
# インデックス： 413
# 予測： 6.0
# Label: 2
# <div id='bb77a942-07ca-40dd-abd2-0c8ef3fe8ea2'></div>
# インデックス： 441
# 予測： 7.0
# Label: 9
# <div id='471d0e26-789b-4522-b099-258f939fdccd'></div>
# インデックス： 444
# 予測： 4.0
# Label: 6
# <div id='62478adb-a4f9-4599-a4f7-89159ed35e42'></div>
# インデックス： 452
# 予測： 6.0
# Label: 0
# <div id='e05645b0-9d74-4ecf-a9b2-1775731b4491'></div>
# インデックス： 454
# 予測： 6.0
# Label: 0
# <div id='6dfa26e5-7ef2-4efe-8734-c85ef469563e'></div>
# インデックス： 457
# 予測： 4.0
# Label: 2
# <div id='a52d1ab5-1b1b-4d51-8b6a-7ef489cd3f9e'></div>
# インデックス： 460
# 予測： 6.0
# Label: 3
# <div id='7826cb99-96ec-497e-ac95-694b1dfb2607'></div>
# インデックス： 525
# 予測： 4.0
# Label: 2
# <div id='310cbb83-8991-4031-aa75-fda270e376d9'></div>
# インデックス： 565
# 予測： 0.0
# Label: 6
# <div id='4f51dd19-1dce-463c-bb08-9f171116f8d1'></div>
# インデックス： 569
# 予測： 6.0
# Label: 3
# <div id='f53aa60d-d57b-4d59-ac0d-3aca905c3383'></div>
# インデックス： 639
# 予測： 2.0
# Label: 4
# <div id='1cc740a2-47d5-4525-b635-b1e1d99310c0'></div>
# インデックス： 664
# 予測： 4.0
# Label: 6
# <div id='1f3faaf2-a4a7-479d-9976-74bab4074bf6'></div>
# インデックス： 670
# 予測： 6.0
# Label: 2
# <div id='3df085e0-4a62-435e-b184-4e5f427a9b36'></div>
# インデックス： 681
# 予測： 6.0
# Label: 0
# <div id='08c9690c-014b-4372-ab04-26c95f872512'></div>
# インデックス： 684
# 予測： 0.0
# Label: 6
# <div id='7069485c-bae1-4834-a4ed-9ecf25755840'></div>
# インデックス： 688
# 予測： 6.0
# Label: 3
# <div id='2a06859c-9b04-45c8-b8f3-7e8badb76915'></div>
# インデックス： 699
# 予測： 6.0
# Label: 3
# C:\Users\y9723\anaconda3\lib\site-packages\ipykernel_launcher.py:19: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# <div id='36316cf0-453a-46d1-af14-b33aecd6de93'></div>
# インデックス： 711
# 予測： 3.0
# Label: 6
# <div id='bcd9169f-2c72-44b1-8547-585885a8fc03'></div>
# インデックス： 715
# 予測： 4.0
# Label: 2
# <div id='3c340cae-7b0f-434f-acbf-bed4f374be2f'></div>
# インデックス： 732
# 予測： 0.0
# Label: 2
# <div id='afbdb2f7-07b7-464e-82fa-8d951819d4f6'></div>
# インデックス： 760
# 予測： 6.0
# Label: 2
# <div id='4fb50090-c091-49da-95f7-cc39f3682f01'></div>
# インデックス： 787
# 予測： 3.0
# Label: 1
# <div id='942b3a24-850a-4d41-9a99-6fcab550a24a'></div>
# インデックス： 859
# 予測： 2.0
# Label: 6
# <div id='c28c5eb5-5c00-4352-a1a3-904612330a31'></div>
# インデックス： 911
# 予測： 4.0
# Label: 6
# <div id='3a2f0362-f1e1-4258-a0d6-518f1137a06e'></div>
# インデックス： 922
# 予測： 6.0
# Label: 0
# <div id='d2295760-d3f2-4f3c-b66c-709beb634471'></div>
# インデックス： 934
# 予測： 6.0
# Label: 3
# <div id='6f1f6c45-84f6-4428-b4ad-7f663aff00ad'></div>
# インデックス： 937
# 予測： 4.0
# Label: 6
# <div id='93999cac-6d81-4320-94ab-ad4b8cae1dbe'></div>
# インデックス： 942
# 予測： 0.0
# Label: 6
# <div id='093bd8d7-11a2-427c-9110-bd1a2260dc7d'></div>
# インデックス： 947
# 予測： 0.0
# Label: 3
# <div id='32a83f1c-ca40-4259-90a5-3d1af16283b5'></div>
# インデックス： 981
# 予測： 4.0
# Label: 6

# %% [markdown]
# 四角形の中を見てみる

# %%
uncorrect_data[0]
# 間違えてもいい　index=23, 42, 89
# 間違えたらだめ　index=12, 40, 43, 67, 68
# 迷うやつ　index=25, 49, 51, 66, 74, 98, 141, 147
mistake_good=[23, 25, 42, 43, 49, 51, 66, 68, 89, 141, 153, 241, 244, 316, 361, 382, 413,  441, 441, 457, 565, 639, 732, 911]
mistake_bad=[12,25, 40,43, 67, 74, 98, 153, 166,  239, 248, 325, 361, 381, 382, 444, 525, 569, 681, 684, 688, 699, 715, 859, 922]
mistake_taf=[43, 66, 147, 155, 222, 248, 332, 344, 359, 378, 381, 396, 404, 452, 454, 460, 569, 639, 664, 670, 711, 760, 787, 922, 934, 937, 942, 947, 981]

# %% [markdown]
# 間違えたものについて分析

# %% [markdown]
# 間違えてもいい　index=23, 42, 43, 68, 89
# 特徴としては、そもそも含まれている点の数、密集度的に少ない場所に写像されている点が多い

# %%
data=[]
# level0がより左側のインデックスで、階層は上のインデックス
test_radius=[0.2]
string_test_radius = [str(radius) for radius in test_radius for _ in range(3)]
# print(string_test_radius)
# level0
level0=string_test_radius
# 予測ラベル格納
# predictions=np.zeros((z_test_np.shape[0],))
z_test_np
# 複製の作成
sub_y_test=y_test_np.copy()
# 割合パラメータ（50, 60, 70, 80, 90, 95）
para=50
# 四角形を作ってから、球状判定領域を作成
array=np.array(z_valid_np.shape)
percentage=np.empty(10)

label_ans = ["正解", "不正解", "解答不可"]
# test_radiusの値の数に応じてパターンを増やす
level1 = [label_ans[j] for i in range(len(test_radius)) for j in range(len(label_ans))]
indices = [level0, level1]
# print(indices)

# データの整理

# 
sample_data = [np.empty((10000, 3)) for _ in range(len(mistake_good))]
# sample_data=array2
# sample_data_prime=array2-z_test_np[0]
# print(sample_data_prime.shape)
# sample_label=array3
sample_label=[np.empty((10000)) for _ in range(len(mistake_good))]
sample_data

for index in range(1):
    for index2, l in enumerate(mistake_good):
        # 四角形内か否かを判定
        array=(z_test_np[l]-test_radius[index] < z_valid_np) & (z_valid_np < z_test_np[l]+test_radius[index])
    #     print(array.shape)
        array1=array.all(axis=1)
        array2=z_valid_np[array1] 
        # 1103
        sample_data[index2]=array2
        total_elements=array2.shape[0]
        # labelの確認
        array3=y_valid_np[array1]
        # 1103
        sample_label[index2]=array3
    #     print(type(array3))
        counts=np.bincount(array3, minlength=10)
        # 結果の表示
        for i in range(10):
            percentage[i] = (counts[i] / total_elements) * 100
            print(f"クラス {i} は {counts[i]} 回出現しました。割合は {percentage[i]:.2f}% です。")
        print("--------------------------------------------------------------------")
        # percentageがpara%を超えていればそのラベルを予測ラベルとし、そうでない場合は、他のラベルの割合比べたり、不可能ラベルとしたり
        #     条件分岐
        max_value = np.max(percentage)
        print(f"max_value:{max_value}")
        max_index = np.argmax(percentage)
        print(f"max_index:{max_index}")
        print(f"解答は{y_test_np[l]}となる")
        print(f"インデックスは{l}")
# Out:
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 0 回出現しました。割合は 0.00% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 58 回出現しました。割合は 98.31% です。
# クラス 6 は 0 回出現しました。割合は 0.00% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 1 回出現しました。割合は 1.69% です。
# --------------------------------------------------------------------
# max_value:98.30508474576271
# max_index:5
# 解答は9となる
# インデックスは23
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 44 回出現しました。割合は 75.86% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 12 回出現しました。割合は 20.69% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 2 回出現しました。割合は 3.45% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:75.86206896551724
# max_index:2
# 解答は4となる
# インデックスは25
# クラス 0 は 3 回出現しました。割合は 1.25% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 3 回出現しました。割合は 1.25% です。
# クラス 3 は 1 回出現しました。割合は 0.42% です。
# クラス 4 は 5 回出現しました。割合は 2.08% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 228 回出現しました。割合は 95.00% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:95.0
# max_index:6
# 解答は3となる
# インデックスは42
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 0 回出現しました。割合は 0.00% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 0 回出現しました。割合は 0.00% です。
# クラス 7 は 6 回出現しました。割合は 1.15% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 517 回出現しました。割合は 98.85% です。
# --------------------------------------------------------------------
# max_value:98.8527724665392
# max_index:9
# 解答は7となる
# インデックスは43
# クラス 0 は 2 回出現しました。割合は 0.97% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 34 回出現しました。割合は 16.43% です。
# クラス 3 は 1 回出現しました。割合は 0.48% です。
# クラス 4 は 7 回出現しました。割合は 3.38% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 163 回出現しました。割合は 78.74% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:78.74396135265701
# max_index:6
# 解答は2となる
# インデックスは49
# クラス 0 は 2 回出現しました。割合は 0.98% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 140 回出現しました。割合は 68.63% です。
# クラス 3 は 1 回出現しました。割合は 0.49% です。
# クラス 4 は 29 回出現しました。割合は 14.22% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 32 回出現しました。割合は 15.69% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:68.62745098039215
# max_index:2
# 解答は4となる
# インデックスは51
# クラス 0 は 23 回出現しました。割合は 23.96% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 0 回出現しました。割合は 0.00% です。
# クラス 3 は 1 回出現しました。割合は 1.04% です。
# クラス 4 は 1 回出現しました。割合は 1.04% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 71 回出現しました。割合は 73.96% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:73.95833333333334
# max_index:6
# 解答は2となる
# インデックスは66
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 0 回出現しました。割合は 0.00% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 1 回出現しました。割合は 0.04% です。
# クラス 6 は 0 回出現しました。割合は 0.00% です。
# クラス 7 は 2610 回出現しました。割合は 99.85% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 3 回出現しました。割合は 0.11% です。
# --------------------------------------------------------------------
# max_value:99.84697781178271
# max_index:7
# 解答は9となる
# インデックスは68
# クラス 0 は 2 回出現しました。割合は 2.86% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 60 回出現しました。割合は 85.71% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 1 回出現しました。割合は 1.43% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 7 回出現しました。割合は 10.00% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:85.71428571428571
# max_index:2
# 解答は6となる
# インデックスは89
# クラス 0 は 2 回出現しました。割合は 2.44% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 0 回出現しました。割合は 0.00% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 80 回出現しました。割合は 97.56% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:97.5609756097561
# max_index:6
# 解答は0となる
# インデックスは141
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 0 回出現しました。割合は 0.00% です。
# クラス 3 は 17 回出現しました。割合は 80.95% です。
# クラス 4 は 3 回出現しました。割合は 14.29% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 1 回出現しました。割合は 4.76% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:80.95238095238095
# max_index:3
# 解答は4となる
# インデックスは153
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 4 回出現しました。割合は 0.79% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 500 回出現しました。割合は 98.62% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 3 回出現しました。割合は 0.59% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:98.61932938856016
# max_index:4
# 解答は6となる
# インデックスは241
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 401 回出現しました。割合は 98.77% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 4 回出現しました。割合は 0.99% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 1 回出現しました。割合は 0.25% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:98.76847290640394
# max_index:2
# 解答は6となる
# インデックスは244
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 0 回出現しました。割合は 0.00% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 0 回出現しました。割合は 0.00% です。
# クラス 7 は 13 回出現しました。割合は 76.47% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 4 回出現しました。割合は 23.53% です。
# --------------------------------------------------------------------
# max_value:76.47058823529412
# max_index:7
# 解答は9となる
# インデックスは316
# クラス 0 は 2 回出現しました。割合は 0.29% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 12 回出現しました。割合は 1.76% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 3 回出現しました。割合は 0.44% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 664 回出現しました。割合は 97.50% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:97.50367107195301
# max_index:6
# 解答は2となる
# インデックスは361
# クラス 0 は 1816 回出現しました。割合は 96.80% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 3 回出現しました。割合は 0.16% です。
# クラス 3 は 1 回出現しました。割合は 0.05% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 56 回出現しました。割合は 2.99% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:96.80170575692964
# max_index:0
# 解答は2となる
# インデックスは382
# クラス 0 は 3 回出現しました。割合は 1.72% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 11 回出現しました。割合は 6.32% です。
# クラス 3 は 1 回出現しました。割合は 0.57% です。
# クラス 4 は 9 回出現しました。割合は 5.17% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 150 回出現しました。割合は 86.21% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:86.20689655172413
# max_index:6
# 解答は2となる
# インデックスは413
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 0 回出現しました。割合は 0.00% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 1 回出現しました。割合は 0.05% です。
# クラス 6 は 0 回出現しました。割合は 0.00% です。
# クラス 7 は 1856 回出現しました。割合は 99.89% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 1 回出現しました。割合は 0.05% です。
# --------------------------------------------------------------------
# max_value:99.89235737351991
# max_index:7
# 解答は9となる
# インデックスは441
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 0 回出現しました。割合は 0.00% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 1 回出現しました。割合は 0.05% です。
# クラス 6 は 0 回出現しました。割合は 0.00% です。
# クラス 7 は 1856 回出現しました。割合は 99.89% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 1 回出現しました。割合は 0.05% です。
# --------------------------------------------------------------------
# max_value:99.89235737351991
# max_index:7
# 解答は9となる
# インデックスは441
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 42 回出現しました。割合は 17.14% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 192 回出現しました。割合は 78.37% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 11 回出現しました。割合は 4.49% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:78.36734693877551
# max_index:4
# 解答は2となる
# インデックスは457
# クラス 0 は 285 回出現しました。割合は 62.78% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 1 回出現しました。割合は 0.22% です。
# クラス 3 は 1 回出現しました。割合は 0.22% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 167 回出現しました。割合は 36.78% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:62.77533039647577
# max_index:0
# 解答は6となる
# インデックスは565
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 500 回出現しました。割合は 98.43% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 4 回出現しました。割合は 0.79% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 4 回出現しました。割合は 0.79% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:98.4251968503937
# max_index:2
# 解答は4となる
# インデックスは639
# クラス 0 は 291 回出現しました。割合は 93.27% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 0 回出現しました。割合は 0.00% です。
# クラス 3 は 0 回出現しました。割合は 0.00% です。
# クラス 4 は 0 回出現しました。割合は 0.00% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 21 回出現しました。割合は 6.73% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:93.26923076923077
# max_index:0
# 解答は2となる
# インデックスは732
# クラス 0 は 0 回出現しました。割合は 0.00% です。
# クラス 1 は 0 回出現しました。割合は 0.00% です。
# クラス 2 は 25 回出現しました。割合は 12.76% です。
# クラス 3 は 1 回出現しました。割合は 0.51% です。
# クラス 4 は 145 回出現しました。割合は 73.98% です。
# クラス 5 は 0 回出現しました。割合は 0.00% です。
# クラス 6 は 25 回出現しました。割合は 12.76% です。
# クラス 7 は 0 回出現しました。割合は 0.00% です。
# クラス 8 は 0 回出現しました。割合は 0.00% です。
# クラス 9 は 0 回出現しました。割合は 0.00% です。
# --------------------------------------------------------------------
# max_value:73.9795918367347
# max_index:4
# 解答は6となる
# インデックスは911

# %%
import numpy as np
import matplotlib.pyplot as plt

# 正方形の一辺の長さ
side_length = 0.4

select=2

x = np.linspace(0.2, 0.2, 100)
y = np.linspace(0.2, 0.2, 100)
X, Y = np.meshgrid(x, y)

# Z座標をすべて0に設定
Z = np.zeros_like(X)

fig = plt.figure()
ax = fig.add_subplot(111)

# 正方形をプロット
ax.contourf(X, Y, Z, levels=[-0.4, 0.4], colors=['none'])



for i in range(sample_data[select].shape[0]):
    data_x=sample_data[select][i, 0]-z_test_np[mistake_good[select], 0]
    data_y=sample_data[select][i, 1]-z_test_np[mistake_good[select], 1]
    data_z=sample_data[select][i, 2]-z_test_np[mistake_good[select], 2]
    ax.scatter(data_x, data_y, color=colors[sample_label[select][i]])

ax.set_xlim(-side_length / 2, side_length / 2)
ax.set_ylim(-side_length / 2, side_length / 2)
ax.scatter(0, 0, marker="*")

plt.gca().set_aspect('equal', adjustable='box')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
import numpy as np
import mpl_toolkits.mplot3d
import matplotlib.pyplot as plt

select=2

rcParams['figure.figsize'] = 10, 10

x = np.linspace(-0.2, 0.2, 100)
y = np.linspace(-0.2, 0.2, 100)
X, Y = np.meshgrid(x, y)
Z1 = np.ones_like(X)
Z2 = -1 * np.ones_like(X)


fig=plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(z_test_np[mistake_good[select], 0], z_test_np[mistake_good[select], 1], z_test_np[mistake_good[select], 2], s=300, marker="*", edgecolors="white")
x_prime=z_test_np[mistake_good[select], 0]
y_prime=z_test_np[mistake_good[select], 1]
z_prime=z_test_np[mistake_good[select], 2]
ax.plot_surface(X+x_prime, Y+y_prime, Z1+z_prime-0.8, alpha=0.4)
ax.plot_surface(X+x_prime, Y+y_prime, Z2+z_prime+0.8, alpha=0.4)
ax.plot_surface(X+x_prime, 0.2+y_prime, Y+z_prime, alpha=0.4)
ax.plot_surface(X+x_prime, -0.2+y_prime, Y+z_prime, alpha=0.4)
ax.plot_surface(0.2+x_prime, X+y_prime, Y+z_prime, alpha=0.4)
ax.plot_surface(-0.2+x_prime, X+y_prime, Y+z_prime, alpha=0.4)

for i in range(class_num):    ax.scatter(z_valid_np[y_valid_np==i, 0], z_valid_np[y_valid_np==i, 1], z_valid_np[y_valid_np==i, 2], color=colors[i], label=class_names[i], alpha=0.06)


ax.set_xlim(-2, 2)
ax.set_ylim(-2, 2)
ax.set_zlim(-2, 2)

plt.show()

# %% [markdown]
# 間違えたらダメ　index=12, 40, 43, 67, 68

# %%
data=[]
# level0がより左側のインデックスで、階層は上のインデックス
test_radius=[0.2]
string_test_radius = [str(radius) for radius in test_radius for _ in range(3)]
# print(string_test_radius)
# level0
level0=string_test_radius
# 予測ラベル格納
# predictions=np.zeros((z_test_np.shape[0],))
z_test_np
# 複製の作成
sub_y_test=y_test_np.copy()
# 割合パラメータ（50, 60, 70, 80, 90, 95）
para=50
# 四角形を作ってから、球状判定領域を作成
array=np.array(z_valid_np.shape)
percentage=np.empty(10)

label_ans = ["正解", "不正解", "解答不可"]
# test_radiusの値の数に応じてパターンを増やす
level1 = [label_ans[j] for i in range(len(test_radius)) for j in range(len(label_ans))]
indices = [level0, level1]
# print(indices)

# データの整理

# 
sample_data = [np.empty((10000, 3)) for _ in range(len(mistake_good))]
# sample_data=array2
# sample_data_prime=array2-z_test_np[0]
# print(sample_data_prime.shape)
# sample_label=array3
sample_label=[np.empty((10000)) for _ in range(len(mistake_good))]
sample_data

for index in range(1):
    for index2, l in enumerate(mistake_bad):
        # 四角形内か否かを判定
        array=(z_test_np[l]-test_radius[index] < z_valid_np) & (z_valid_np < z_test_np[l]+test_radius[index])
    #     print(array.shape)
        array1=array.all(axis=1)
        array2=z_valid_np[array1] 
        # 1103
        sample_data[index2]=array2
        total_elements=array2.shape[0]
        # labelの確認
        array3=y_valid_np[array1]
        # 1103
        sample_label[index2]=array3
    #     print(type(array3))
        counts=np.bincount(array3, minlength=10)
        # 結果の表示
        for i in range(10):
            percentage[i] = (counts[i] / total_elements) * 100
            print(f"クラス {i} は {counts[i]} 回出現しました。割合は {percentage[i]:.2f}% です。")
        print("--------------------------------------------------------------------")
        # percentageがpara%を超えていればそのラベルを予測ラベルとし、そうでない場合は、他のラベルの割合比べたり、不可能ラベルとしたり
        #     条件分岐
        max_value = np.max(percentage)
        print(f"max_value:{max_value}")
        max_index = np.argmax(percentage)
        print(f"max_index:{max_index}")
        print(f"解答は{y_test_np[l]}となる")
        print(f"インデックスは{l}")

# %% [markdown]
# 迷うもの
# 特徴としては、max_valueが低く、かつ特徴として複数持っている？

# %%
data=[]
# level0がより左側のインデックスで、階層は上のインデックス
test_radius=[0.2]
string_test_radius = [str(radius) for radius in test_radius for _ in range(3)]
# print(string_test_radius)
# level0
level0=string_test_radius
# 予測ラベル格納
# predictions=np.zeros((z_test_np.shape[0],))
z_test_np
# 複製の作成
sub_y_test=y_test_np.copy()
# 割合パラメータ（50, 60, 70, 80, 90, 95）
para=50
# 四角形を作ってから、球状判定領域を作成
array=np.array(z_valid_np.shape)
percentage=np.empty(10)

label_ans = ["正解", "不正解", "解答不可"]
# test_radiusの値の数に応じてパターンを増やす
level1 = [label_ans[j] for i in range(len(test_radius)) for j in range(len(label_ans))]
indices = [level0, level1]
# print(indices)

# データの整理

# 
sample_data = [np.empty((10000, 3)) for _ in range(len(mistake_good))]
# sample_data=array2
# sample_data_prime=array2-z_test_np[0]
# print(sample_data_prime.shape)
# sample_label=array3
sample_label=[np.empty((10000)) for _ in range(len(mistake_good))]
sample_data

for index in range(1):
    for index2, l in enumerate(mistake_taf):
        # 四角形内か否かを判定
        array=(z_test_np[l]-test_radius[index] < z_valid_np) & (z_valid_np < z_test_np[l]+test_radius[index])
    #     print(array.shape)
        array1=array.all(axis=1)
        array2=z_valid_np[array1] 
        # 1103
        sample_data[index2]=array2
        total_elements=array2.shape[0]
        # labelの確認
        array3=y_valid_np[array1]
        # 1103
        sample_label[index2]=array3
    #     print(type(array3))
        counts=np.bincount(array3, minlength=10)
        # 結果の表示
        for i in range(10):
            percentage[i] = (counts[i] / total_elements) * 100
            print(f"クラス {i} は {counts[i]} 回出現しました。割合は {percentage[i]:.2f}% です。")
        print("--------------------------------------------------------------------")
        # percentageがpara%を超えていればそのラベルを予測ラベルとし、そうでない場合は、他のラベルの割合比べたり、不可能ラベルとしたり
        #     条件分岐
        max_value = np.max(percentage)
        print(f"max_value:{max_value}")
        max_index = np.argmax(percentage)
        print(f"max_index:{max_index}")
        print(f"解答は{y_test_np[l]}となる")
        print(f"インデックスは{l}")

# %%
import numpy as np
import matplotlib.pyplot as plt

select_taf=0

# 正方形の一辺の長さ
side_length = 0.4

x = np.linspace(0.2, 0.2, 100)
y = np.linspace(0.2, 0.2, 100)
X, Y = np.meshgrid(x, y)

# Z座標をすべて0に設定
Z = np.zeros_like(X)

fig = plt.figure()
ax = fig.add_subplot(111)

# 正方形をプロット
ax.contourf(X, Y, Z, levels=[-0.4, 0.4], colors=['none'])



for i in range(sample_data[select_taf].shape[0]):
    data_x=sample_data[select_taf][i, 0]-z_test_np[mistake_taf[select_taf], 0]
    data_y=sample_data[select_taf][i, 1]-z_test_np[mistake_taf[select_taf], 1]
    data_z=sample_data[select_taf][i, 2]-z_test_np[mistake_taf[select_taf], 2]
    ax.scatter(data_x, data_y, color=colors[sample_label[select_taf][i]])

ax.set_xlim(-side_length / 2, side_length / 2)
ax.set_ylim(-side_length / 2, side_length / 2)
ax.scatter(0, 0, marker="*")

plt.gca().set_aspect('equal', adjustable='box')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
import numpy as np
import mpl_toolkits.mplot3d
import matplotlib.pyplot as plt

select_bad=2

rcParams['figure.figsize'] = 10, 10

x = np.linspace(-0.2, 0.2, 100)
y = np.linspace(-0.2, 0.2, 100)
X, Y = np.meshgrid(x, y)
Z1 = np.ones_like(X)
Z2 = -1 * np.ones_like(X)


fig=plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(z_test_np[mistake_bad[select_bad], 0], z_test_np[mistake_bad[select_bad], 1], z_test_np[mistake_bad[select_bad], 2], s=300, marker="*", edgecolors="white")
x_prime=z_test_np[mistake_bad[select_bad], 0]
y_prime=z_test_np[mistake_bad[select_bad], 1]
z_prime=z_test_np[mistake_bad[select_bad], 2]
ax.plot_surface(X+x_prime, Y+y_prime, Z1+z_prime-0.8, alpha=0.4)
ax.plot_surface(X+x_prime, Y+y_prime, Z2+z_prime+0.8, alpha=0.4)
ax.plot_surface(X+x_prime, 0.2+y_prime, Y+z_prime, alpha=0.4)
ax.plot_surface(X+x_prime, -0.2+y_prime, Y+z_prime, alpha=0.4)
ax.plot_surface(0.2+x_prime, X+y_prime, Y+z_prime, alpha=0.4)
ax.plot_surface(-0.2+x_prime, X+y_prime, Y+z_prime, alpha=0.4)

for i in range(class_num):    ax.scatter(z_valid_np[y_valid_np==i, 0], z_valid_np[y_valid_np==i, 1], z_valid_np[y_valid_np==i, 2], color=colors[i], label=class_names[i], alpha=0.06)


ax.set_xlim(-2, 2)
ax.set_ylim(-2, 2)
ax.set_zlim(-2, 2)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# データの準備
x = np.linspace(-0.5, 0.5, 100)
y = np.linspace(-0.5, 0.5, 100)
X, Y = np.meshgrid(x, y)  # メッシュグリッドを作成
Z1 = np.ones_like(X)
Z2 = -1 * np.ones_like(X)

# サンプルデータの座標
x_sample = sample_data[0, 0]
y_sample = sample_data[0, 1]
z_sample = sample_data[0, 2]

# 新しい3Dプロットを作成
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')



# サーフェスの色を統一する
surface_color = 'white'  # 好きな色に変更できます

# 手動で3Dプロットを作成し、サーフェスの色を指定
ax.plot_surface(X + x_sample, Y + y_sample, Z1 + z_sample - 0.5, alpha=0.4, color=surface_color)
ax.plot_surface(X + x_sample, Y + y_sample, Z2 + z_sample + 0.5, alpha=0.4, color=surface_color)
ax.plot_surface(X + x_sample, 0.5 + y_sample, Y + z_sample, alpha=0.4, color=surface_color)
ax.plot_surface(X + x_sample, -0.5 + y_sample, Y + z_sample, alpha=0.4, color=surface_color)
ax.plot_surface(0.5 + x_sample, X + y_sample, Y + z_sample, alpha=0.4, color=surface_color)
ax.plot_surface(-0.5 + x_sample, X + y_sample, Y + z_sample, alpha=0.4, color=surface_color)

# 他のデータ点を散布図として表示
for i in range(class_num):
    ax.scatter(z_test_np[y_test_np == i, 0], z_test_np[y_test_np == i, 1], z_test_np[y_test_np == i, 2], color=colors[i], label=class_names[i], alpha=0.5)

# サンプルデータの表示
ax.scatter(x_sample, y_sample, z_sample, s=300, marker="*")
    
ax.set_xlim(-2, 2)
ax.set_ylim(-2, 2)
ax.set_zlim(-2, 2)

plt.show()

# %%
# データの準備
x = np.linspace(-0.5, 0.5, 100)
y = np.linspace(-0.5, 0.5, 100)
X, Y = np.meshgrid(x, y)  # メッシュグリッドを作成
Z1 = np.ones_like(X)
Z2 = -1 * np.ones_like(X)

# サンプルデータの座標
x_sample = sample_data[0, 0]
y_sample = sample_data[0, 1]
z_sample = sample_data[0, 2]

# 新しい3Dプロットを作成
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')

# サンプルデータの表示
ax.scatter(x_sample, y_sample, z_sample, s=300, marker="*", edgecolors="white")

# サーフェスの色を統一する
surface_color = 'white'  # 好きな色に変更できます

# 手動で3Dプロットを作成し、サーフェスの色を指定
ax.plot_surface(X + x_sample, Y + y_sample, Z1 + z_sample - 0.5, alpha=0.4, color=surface_color)
ax.plot_surface(X + x_sample, Y + y_sample, Z2 + z_sample + 0.5, alpha=0.4, color=surface_color)
ax.plot_surface(X + x_sample, 0.5 + y_sample, Y + z_sample, alpha=0.4, color=surface_color)
ax.plot_surface(X + x_sample, -0.5 + y_sample, Y + z_sample, alpha=0.4, color=surface_color)
ax.plot_surface(0.5 + x_sample, X + y_sample, Y + z_sample, alpha=0.4, color=surface_color)
ax.plot_surface(-0.5 + x_sample, X + y_sample, Y + z_sample, alpha=0.4, color=surface_color)

# # 他のデータ点を散布図として表示
# for i in range(class_num):
#     ax.scatter(z_test_np[y_test_np == i, 0], z_test_np[y_test_np == i, 1], z_test_np[y_test_np == i, 2], color=colors[i], label=class_names[i], alpha=0.5)


for i in range(2, sample_data.shape[0]):
    ax.scatter(sample_data[i, 0], sample_data[i, 1], sample_data[i, 2], color=colors[sample_label[i]])


ax.set_xlim(-2, 2)
ax.set_ylim(-2, 2)
ax.set_zlim(-2, 2)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 正方形の一辺の長さ
side_length = 1.0

# サンプルデータの座標
x_sample = sample_data[0, 0]
y_sample = sample_data[0, 1]
z_sample = sample_data[0, 2]

x = np.linspace(-side_length / 2, side_length / 2, 100)
y = np.linspace(-side_length / 2, side_length / 2, 100)
X, Y = np.meshgrid(x, y)

# Z座標をすべて0に設定
Z = np.zeros_like(X)

fig = plt.figure()
ax = fig.add_subplot(111)

# 正方形をプロット
ax.contourf(X, Y, Z, levels=[-1, 1], colors=['none'])

for i in range(sample_data.shape[0]):
    ax.scatter(sample_data[i, 0], sample_data[i, 1], color=colors[sample_label[i]])

ax.set_xlim(-side_length / 2, side_length / 2)
ax.set_ylim(-side_length / 2, side_length / 2)

plt.gca().set_aspect('equal', adjustable='box')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 正方形の一辺の長さ
side_length = 2.0

x = np.linspace(-side_length / 2, side_length / 2, 100)
y = np.linspace(-side_length / 2, side_length / 2, 100)
X, Y = np.meshgrid(x, y)

# Z座標をすべて0に設定
Z = np.zeros_like(X)

fig = plt.figure()
ax = fig.add_subplot(111)

# 正方形をプロット
ax.contourf(X, Y, Z, levels=[-1, 1], colors=['none'])

for i in range(sample_data.shape[0]):
    ax.scatter(sample_data[i, 0], sample_data[i, 2], color=colors[sample_label[i]])

ax.set_xlim(-side_length / 2, side_length / 2)
ax.set_ylim(-side_length / 2, side_length / 2)

plt.gca().set_aspect('equal', adjustable='box')
plt.show()

# %%
# 間違えている点をプロットしてみる（間違えている画像を見てみる）
uncorrect_data_vis=np.zeros((len(uncorrect_data), 3))
for i, j in enumerate(uncorrect_data):
    uncorrect_data_vis[i]=z_test_np[j]
uncorrect_data_vis

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


rcParams['figure.figsize'] = 10, 10

# 球体のパラメータ
radius = radius_class_arbitary
phi = np.linspace(0, np.pi, 15)  # 緯度角の範囲
theta = np.linspace(0, 2 * np.pi, 30)  # 経度角の範囲
phi, theta = np.meshgrid(phi, theta)

# クラス名
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# クラス数
class_num=len(class_names)
# 事前に定義された10色のリスト
colors = ["blue","green","red","cyan","magenta","yellow","black",'#f781bf','#a65628','#ff7f00']
# figureを生成する
plt.figure(figsize=(10, 10))
# axをfigureに設定する
ax = plt.subplot(111, projection='3d')
# クラスごとに色を分けてプロット
for i in range(class_num):    
    ax.scatter(z_valid_np[y_valid_np==i, 0], z_valid_np[y_valid_np==i, 1], z_valid_np[y_valid_np==i, 2], color=colors[i], label=class_names[i], alpha=0.09)

# 球体の座標を計算
for i in range(10):
    x = radius[i] * np.sin(phi) * np.cos(theta) + centroids[i, 0]
    y = radius[i] * np.sin(phi) * np.sin(theta) + centroids[i, 1]
    z = radius[i] * np.cos(phi) + centroids[i, 2]
    ax.plot_surface(x, y, z, color=colors[i], alpha=0.1, edgecolors="black")
    ax.scatter(centroids[i, 0], centroids[i, 1], centroids[i, 2], marker='*', color=colors[i], label=class_names[i], s=300, edgecolors="black")

for i in range(uncorrect_data_vis.shape[0]):
    ax.scatter(uncorrect_data_vis[i, 0], uncorrect_data_vis[i, 1], uncorrect_data_vis[i, 2], color=colors[y_test_np[uncorrect_data[i]]])

    
# 凡例を手動で作成
legend_labels = []
for i in range(10):
    legend_labels.append(plt.Line2D([0], [0], marker='o', color=colors[i], markersize=5, label=class_names[i]))

# 星印の凡例も追加
legend_labels.append(plt.Line2D([0], [0], marker='*', color="black", markersize=10, label='Centroid'))

ax.set_xlim([-2, 2])
ax.set_ylim([-2, 2])
ax.set_zlim([-2, 2])
ax.legend(handles=legend_labels)  # 凡例の追加
plt.tight_layout()
plt.show()

# %% [markdown]
# ヒストグラムの作成

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

# 1000個のランダムなデータを生成
data = np.random.randn(1000)

# 0か1のラベルをランダムに割り当て
labels = np.random.choice([0, 1], size=1000)

# ヒストグラムを作成（ラベル0は青、ラベル1は赤）
plt.hist([data[labels == 0], data[labels == 1]], bins=20, edgecolor='black', alpha=0.5, color=['blue', 'red'], label=['Label 0', 'Label 1'])

# グラフにタイトルや軸ラベルを追加
plt.title('Histogram of 1000 Data Points with Labels')
plt.xlabel('Values')
plt.ylabel('Frequency')

# 凡例を表示
plt.legend()

# ヒストグラムを表示
plt.show()
